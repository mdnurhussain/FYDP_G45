# %% [markdown]
# # Medical Image Fusion
# A project to fuse a pair of medical images (CT-MRI, PET-MRI, SPECT-MRI) into a single image for better interpretation.
#
# ### Model Definition
# Using a 4-stage model to extract features, learn, and reconstruct images.
#
# ### Model Structure
# * Muili-Stream Encoder: Used two separate pre-trained CNNs for extracting feature maps at various resolutions.
# * Feature Fusion: Combines the feature maps extracted by encoders.
# * Custom UNet Decoder: Upscales and reconstructs the image by using the feature maps.
# * Image Refiner (Optional): Refines the final image based of redundant feature maps.

# %% [markdown]
# ## Environment Initalization

# %%
import os
import cv2
import gc
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

import tensorflow as tf

# GPU Setup & Memory Growth
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print(f"TensorFlow is using GPU: {gpus[0].name}")
    except RuntimeError as e:
        print(e)
else:
    print("TensorFlow is using CPU")
# Out:
# TensorFlow is using GPU: /physical_device:GPU:0

# %% [markdown]
# ## Dataset Preprocessing

# %%
# CT-MRI
dir_1 = '/kaggle/input/datasets/mdrafsanyeasir/thesis45-medical-image/Havard-Medical-Image-Fusion-Datasets-main/CT-MRI/CT'
dir_2 = '/kaggle/input/datasets/mdrafsanyeasir/thesis45-medical-image/Havard-Medical-Image-Fusion-Datasets-main/CT-MRI/MRI'


# PET-MRI
# dir_1 = '/kaggle/input/datasets/mdrafsanyeasir/thesis45-medical-image/Havard-Medical-Image-Fusion-Datasets-main/PET-MRI/MRI'
# dir_2 = '/kaggle/input/datasets/mdrafsanyeasir/thesis45-medical-image/Havard-Medical-Image-Fusion-Datasets-main/PET-MRI/PET'


# SPECT-MRI
# dir_1 = '/kaggle/input/datasets/mdrafsanyeasir/thesis45-medical-image/Havard-Medical-Image-Fusion-Datasets-main/SPECT-MRI/MRI'
# dir_2 = '/kaggle/input/datasets/mdrafsanyeasir/thesis45-medical-image/Havard-Medical-Image-Fusion-Datasets-main/SPECT-MRI/SPECT'

# %% [markdown]
# ### Muti-Stream Data Loading

# %%
from tensorflow.keras.preprocessing.image import load_img, img_to_array

def load_and_process_fusion_data_v1(dir_1, dir_2, target_size=(256, 256)):
    """
    Dual-Stream loader for Double Grayscale medical image fusion.
    Returns X1 (3-Ch), X2 (3-Ch), and y (Fused Target 3-Ch).
    """
    filenames = sorted(os.listdir(dir_1))
    num_samples = len(filenames)
    
    # 1. PRE-ALLOCATE MEMORY
    # All arrays must be 3-channel to satisfy the pre-trained ImageNet encoders
    X1 = np.empty((num_samples, target_size[0], target_size[1], 3), dtype=np.float32) 
    X2 = np.empty((num_samples, target_size[0], target_size[1], 3), dtype=np.float32) 
    y  = np.empty((num_samples, target_size[0], target_size[1], 3), dtype=np.float32) 
    
    for i, fname in enumerate(tqdm(filenames, desc="Processing Images (gray-gray) ...")):
        path_dir_1 = os.path.join(dir_1, fname)
        path_dir_2 = os.path.join(dir_2, fname)
        
        # Load images directly into numpy arrays [0, 255]
        x1_arr = img_to_array(load_img(path_dir_1, color_mode="grayscale", target_size=target_size))
        x2_arr = img_to_array(load_img(path_dir_2, color_mode="grayscale", target_size=target_size))
        
        # --- INPUT 1: Grayscale Image ---
        # Repeat the 1-channel into 3 identical channels for pretrained CNNs
        X1[i] = np.repeat(x1_arr, 3, axis=-1) 
        
        # --- INPUT 2: Grayscale Image ---
        X2[i] = np.repeat(x2_arr, 3, axis=-1)
        
        # --- TARGET CREATION ---
        
        # FUSION
        
        ## OPTION A: The Maximum Rule (Default)
        # Ensures that the brightest structural edge from either scan survives
        fused = np.maximum(x1_arr, x2_arr)
        
        ## OPTION B: The Averaging Rule (Uncomment to test)
        # Blends the structural intensities evenly
        # fused = (x1_arr + x2_arr) / 2.0
        
        # Stacking for 3-ch image
        y[i] = np.repeat(fused, 3, axis=-1)

    gc.collect()
    
    return X1, X2, y



def load_and_process_fusion_data_v2(gray_img_dir, color_img_dir, target_size=(256, 256)):
    """
    Dual-Stream loader for Grayscale and RGB medical image fusion.
    Returns X1 (3-Ch), X2 (3-Ch), and y (Fused Target 3-Ch).
    """
    filenames = sorted(os.listdir(gray_img_dir))
    num_samples = len(filenames)
    
    # 1. PRE-ALLOCATE MEMORY
    # All arrays must be 3-channel to satisfy the pre-trained ImageNet encoders
    X1 = np.empty((num_samples, target_size[0], target_size[1], 3), dtype=np.float32) 
    X2 = np.empty((num_samples, target_size[0], target_size[1], 3), dtype=np.float32) 
    y  = np.empty((num_samples, target_size[0], target_size[1], 3), dtype=np.float32) 
    
    for i, fname in enumerate(tqdm(filenames, desc="Processing Images (gray-rgb) ...")):
        path_gray = os.path.join(gray_img_dir, fname)
        path_color = os.path.join(color_img_dir, fname)
        
        # Load images directly into numpy arrays [0, 255]
        x1_arr = img_to_array(load_img(path_gray, color_mode="grayscale", target_size=target_size))
        x2_arr = img_to_array(load_img(path_color, color_mode="rgb", target_size=target_size))
        
        # --- INPUT 1: Grayscale Image ---
        # Repeat the 1-channel into 3 identical channels for pretrained CNNs
        X1[i] = np.repeat(x1_arr, 3, axis=-1) 
        
        # --- INPUT 2: Color Image ---
        X2[i] = x2_arr 
        
        # --- TARGET CREATION (The OpenCV Math) ---
        # OpenCV's float32 color conversions require values to be strictly between 0.0 and 1.0
        x1_norm = x1_arr / 255.0
        x2_norm = x2_arr / 255.0
        
        # 1. Convert RGB to YCrCb using cv2
        # (Note: Keras load_img returns RGB, so we explicitly use COLOR_RGB2YCrCb)
        x2_ycrcb = cv2.cvtColor(x2_norm, cv2.COLOR_RGB2YCrCb)
        
        # 2. Extract Y (Structure), Cr and Cb (Color)
        # Using [:, :, 0:1] keeps the trailing dimension (256, 256, 1) instead of flat (256, 256)
        Y_x2  = x2_ycrcb[:, :, 0:1]
        Cr_x2 = x2_ycrcb[:, :, 1:2]
        Cb_x2 = x2_ycrcb[:, :, 2:3]
        
        # The grayscale natively serves as our structural Y channel
        Y_x1= x1_norm
        
        # 3. FUSION
        
        # OPTION A: The Maximum Rule (Default)
        # Ensures that the brightest structural edge from either scan survives
        Y_fused = np.maximum(Y_x1, Y_x2)
        
        # OPTION B: The Averaging Rule (Uncomment to test)
        # Blends the structural intensities evenly
        # Y_fused = (Y_x1 + Y_x2) / 2.0
        
        # 4. Stack the fused structure back together with the metabolic color
        target_ycrcb = np.concatenate([Y_fused, Cr_x2, Cb_x2], axis=-1)
        
        # 5. Convert back to RGB using cv2 and scale back to 255
        target_rgb = cv2.cvtColor(target_ycrcb, cv2.COLOR_YCrCb2RGB)
        
        # Clip guarantees floating point math doesn't accidentally yield 255.0001 (which crashes matplotlib later)
        y[i] = np.clip(target_rgb * 255.0, 0.0, 255.0)

    gc.collect()
    
    return X1, X2, y

def load_and_process_fusion_data_v3(dir_1, dir_2, target_size=(256, 256)):
    """
    Universal Dual-Stream loader for ANY combination of Grayscale and RGB images.
    Returns X1 (3-Ch), X2 (3-Ch), and y (Fused Target 3-Ch).
    """
    filenames = sorted(os.listdir(dir_1))
    num_samples = len(filenames)
    
    X1 = np.empty((num_samples, target_size[0], target_size[1], 3), dtype=np.float32) 
    X2 = np.empty((num_samples, target_size[0], target_size[1], 3), dtype=np.float32) 
    y  = np.empty((num_samples, target_size[0], target_size[1], 3), dtype=np.float32) 
    
    for i, fname in enumerate(tqdm(filenames, desc="Processing Images (universal) ...")):
        path_1 = os.path.join(dir_1, fname)
        path_2 = os.path.join(dir_2, fname)
        
        # 1. Load BOTH as RGB (Keras will duplicate channels for grayscale images automatically)
        x1_arr = img_to_array(load_img(path_1, color_mode="rgb", target_size=target_size))
        x2_arr = img_to_array(load_img(path_2, color_mode="rgb", target_size=target_size))
        
        # Save exact inputs to RAM
        X1[i] = x1_arr 
        X2[i] = x2_arr 
        
        # 2. Normalize to [0.0, 1.0] for OpenCV
        x1_norm = x1_arr / 255.0
        x2_norm = x2_arr / 255.0
        
        # 3. Convert both to YCrCb
        ycrcb_1 = cv2.cvtColor(x1_norm, cv2.COLOR_RGB2YCrCb)
        ycrcb_2 = cv2.cvtColor(x2_norm, cv2.COLOR_RGB2YCrCb)
        
        # Extract channels
        Y1, Cr1, Cb1 = ycrcb_1[:, :, 0:1], ycrcb_1[:, :, 1:2], ycrcb_1[:, :, 2:3]
        Y2, Cr2, Cb2 = ycrcb_2[:, :, 0:1], ycrcb_2[:, :, 1:2], ycrcb_2[:, :, 2:3]
        
        # 4. STRUCTURAL FUSION (The Maximum Rule for Luminance)
        Y_fused = np.maximum(Y1, Y2)
        
        # 5. CHROMINANCE FUSION (The Saturation Mask)
        # Calculate how far each pixel is from absolute gray (0.5)
        # The sum of absolute differences gives us a "Color Intensity" score
        saturation_1 = np.abs(Cr1 - 0.5) + np.abs(Cb1 - 0.5)
        saturation_2 = np.abs(Cr2 - 0.5) + np.abs(Cb2 - 0.5)
        
        # Create a boolean mask: True if Image 2 has more color, False if Image 1 has more color
        mask = saturation_2 > saturation_1
        
        # Use np.where to dynamically route the original, unaltered color channels
        Cr_fused = np.where(mask, Cr2, Cr1)
        Cb_fused = np.where(mask, Cb2, Cb1)
        
        # 6. Stack and convert back to RGB
        target_ycrcb = np.concatenate([Y_fused, Cr_fused, Cb_fused], axis=-1)
        target_rgb = cv2.cvtColor(target_ycrcb, cv2.COLOR_YCrCb2RGB)
        
        y[i] = np.clip(target_rgb * 255.0, 0.0, 255.0)

    gc.collect()
    
    return X1, X2, y

# %% [markdown]
# ### Splitting into Train, Test and Validation sets

# %%
from sklearn.model_selection import train_test_split

# X1, X2, y = load_and_process_fusion_data_v1(dir_1, dir_2)    # For CT-MRI only
# X1, X2, y = load_and_process_fusion_data_v2(dir_1, dir_2)    # For PET-MRI, SPECT-MRI only

X1, X2, y = load_and_process_fusion_data_v3(dir_1, dir_2)    # Universal

# 1. Split the data using a strict random state to keep them aligned
X1_train, X1_temp, X2_train, X2_temp, y_train, y_temp = train_test_split(
    X1, X2, y, test_size=0.30, random_state=42
)

# 2. Split the temp arrays into Validation and Test
X1_test, X1_val, X2_test, X2_val, y_test, y_val = train_test_split(
    X1_temp, X2_temp, y_temp, test_size=(1/3), random_state=42
)

print(f"X1_train shape: {X1_train.shape} (70%)")
print(f"X1_test shape:  {X1_test.shape} (20%)")
print(f"X1_val shape:   {X1_val.shape} (10%)")
print()

print(f"X2_train shape: {X2_train.shape} (70%)")
print(f"X2_test shape:  {X2_test.shape} (20%)")
print(f"X2_val shape:   {X2_val.shape} (10%)")
print()

print(f"y_train shape: {y_train.shape} (70%)")
print(f"y_test shape:  {y_test.shape} (20%)")
print(f"y_val shape:   {y_val.shape} (10%)")
# Out:
# Processing Images (universal) ...: 100%|██████████| 184/184 [00:02<00:00, 62.11it/s]
# X1_train shape: (128, 256, 256, 3) (70%)
# X1_test shape:  (37, 256, 256, 3) (20%)
# X1_val shape:   (19, 256, 256, 3) (10%)
#
# X2_train shape: (128, 256, 256, 3) (70%)
# X2_test shape:  (37, 256, 256, 3) (20%)
# X2_val shape:   (19, 256, 256, 3) (10%)
#
# y_train shape: (128, 256, 256, 3) (70%)
# y_test shape:  (37, 256, 256, 3) (20%)
# y_val shape:   (19, 256, 256, 3) (10%)

# %% [markdown]
# ### (Optional) Datasets Verification

# %%
import random

def plot_fusion_triplet(x1_array, x2_array, target_array, num_samples=2):
    """
    Plots a row of [X1, X2, Fused Target] to verify alignment and color logic.
    """
    # Pick random indices to check
    # random.seed(213)
    indices = random.sample(range(len(x1_array)), num_samples)
    
    plt.figure(figsize=(15, 5 * num_samples))
    
    for row, idx in enumerate(indices):
        # Scale down to [0.0, 1.0] solely for matplotlib's float32 rendering requirements
        img_mri = x1_array[idx] / 255.0
        img_pet = x2_array[idx] / 255.0
        img_fused = target_array[idx] / 255.0
        
        # Plot X1
        plt.subplot(num_samples, 3, row * 3 + 1)
        plt.imshow(img_mri)
        plt.title(f"X1 - Idx {idx}")
        plt.axis('off')
        
        # Plot X2
        plt.subplot(num_samples, 3, row * 3 + 2)
        plt.imshow(img_pet)
        plt.title(f"X2 - Idx {idx}")
        plt.axis('off')
        
        # Plot y (Fused Target)
        plt.subplot(num_samples, 3, row * 3 + 3)
        plt.imshow(img_fused)
        plt.title(f"y: Fused Ground Truth - Idx {idx}")
        plt.axis('off')
        
    plt.tight_layout()
    plt.show()

# Run the plotter to check your training data!
plot_fusion_triplet(X1_test, X2_test, y_test, num_samples=1)
plot_fusion_triplet(X1_train, X2_train, y_train, num_samples=1)
plot_fusion_triplet(X1_val, X2_val, y_val, num_samples=1)

# %% [markdown]
# ### Image Normalization

# %%
# ==========================================
#  IMAGE NORMALIZATION FOR DENSENET121
# ==========================================
from keras.applications.densenet import preprocess_input
import numpy as np

# Apply DenseNet specific preprocessing to both image streams
X1_train = preprocess_input(X1_train.copy())
X1_test = preprocess_input(X1_test.copy())
X1_val = preprocess_input(X1_val.copy())

X2_train = preprocess_input(X2_train.copy())
X2_test = preprocess_input(X2_test.copy())
X2_val = preprocess_input(X2_val.copy())

# Target mask/ground truth normalization remains basic scaling [0, 1]
y_val = y_val.astype(np.float32) / 255.0
y_test = y_test.astype(np.float32) / 255.0
y_train = y_train.astype(np.float32) / 255.0

# %% [markdown]
# ### Dynamic Runtime Augmentation

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# 1. Define the augmentation parameters
aug_args = dict(
    rotation_range=15,       # Rotate up to 10 degrees
    width_shift_range=0.1,  # Shift left/right by 5%
    height_shift_range=0.05, # Shift up/down by 5%
    zoom_range=0.05,         # Zoom in/out by 5%
    horizontal_flip=True,    # Left/Right flip is usually safe for most axial medical scans
    fill_mode='nearest'      # How to fill missing pixels after shifting
)

# 2. Instantiate generator
datagen = ImageDataGenerator(**aug_args)

seed_value = 42 # Must for synchronizing the generators
batch_size = 4 

# 3. Flow from the RAM arrays
x1_gen = datagen.flow(X1_train, batch_size=batch_size, seed=seed_value, shuffle=True)
x2_gen = datagen.flow(X2_train, batch_size=batch_size, seed=seed_value, shuffle=True)
target_gen = datagen.flow(y_train, batch_size=batch_size, seed=seed_value, shuffle=True)

# 3. Zip them into a Dual-Stream Generator
def dual_stream_train_generator(x1_gen, x2_gen, t_gen):
    while True:
        # Must use a Dictionary matching Input(name="...") layers 
        inputs_dict = {
            "input_x1": next(x1_gen),
            "input_x2": next(x2_gen)
        }
        
        yield (inputs_dict, next(t_gen))

train_fusion_gen = dual_stream_train_generator(x1_gen, x2_gen, target_gen)

# (Optional) Test the generator to make sure the shapes are correct
sample_inputs, sample_targets = next(train_fusion_gen)

print(f"Input 1 shape: {sample_inputs['input_x1'].shape}") # Should be (batch_size, x, x, 3)
print(f"Input 2 shape: {sample_inputs['input_x2'].shape}") # Should be (batch_size, x, x, 3)
print(f"Target batch shape:  {sample_targets.shape}")   # Should be (batch_size, x, x, 3)
# Out:
# Input 1 shape: (4, 256, 256, 3)
# Input 2 shape: (4, 256, 256, 3)
# Target batch shape:  (4, 256, 256, 3)

# %% [markdown]
# ## Model Creation

# %% [markdown]
# ### Model Structure

# %%
# =====================================================================
# DENSENET121 MULTI-STREAM ENCODER & CUSTOM U-NET DECODER (FULLY FIXED)
# =====================================================================
from tensorflow.keras import applications as app
from tensorflow.keras import Model
from tensorflow.keras.layers import Input, Concatenate, Conv2D, BatchNormalization, Activation, Conv2DTranspose

# Define the input shape dynamically based on your validation dataset
input_shape = X1_val.shape[1:]

# --- Stream 1: Left Encoder (e.g., CT / PET) ---
input_x1 = Input(shape=input_shape, name="input_x1")
left_encoder = app.DenseNet121(weights='imagenet', include_top=False, input_tensor=input_x1)

# Append "_left" suffix to every layer name to prevent Keras naming conflicts
for layer in left_encoder.layers[1:]:
    layer.name = layer.name + "_left"
left_fmap = left_encoder.output


# --- Stream 2: Right Encoder (e.g., MRI) ---
input_x2 = Input(shape=input_shape, name="input_x2")
right_encoder = app.DenseNet121(weights='imagenet', include_top=False, input_tensor=input_x2)

# Append "_right" suffix to every layer name to prevent Keras naming conflicts
for layer in right_encoder.layers[1:]:
    layer.name = layer.name + "_right"
right_fmap = right_encoder.output


# --- Stage 2: FEATURE FUSION ---

if int(left_fmap.shape[-2]) != int(right_fmap.shape[-2]):
    raise ValueError(f"Uncompatible Encoders: The Encoders are not compatible with each other")
    
combined_fmap = Concatenate(axis=-1, name="feature_map_combine")([left_fmap, right_fmap])

# Params for Decoder
fmap = min(2048, int(left_fmap.shape[-1]) + int(right_fmap.shape[-1])) 
res = int(combined_fmap.shape[-2])
target_res = int(y_val.shape[1])

# Feature Refiner
x = Conv2D(fmap, kernel_size=(3, 3), padding='same', name="feature_map_refiner")(combined_fmap)
x = BatchNormalization()(x)
x = Activation('relu')(x)


# --- Stage 3: DYNAMIC CUSTOM U-NET DECODER ---

# Image reconstruction
while res < target_res:
    res *= 2
    fmap = max(16, int(fmap / 2))

    # Deconvolution and Upscalling
    x = Conv2DTranspose(fmap, kernel_size=(3, 3), padding='same', strides=2, name=f"decoder_{res}")(x)
    
    # Dynamic Search for the Skip Connection on Left Stream
    target_layer_name_left = None
    
    # Traverse backwards to find the deepest layer at the target resolution
    for layer in left_encoder.layers[::-1]:
        shape = layer.output.shape
        if len(shape) == 4 and shape[1] == res and shape[2] == res:
            target_layer_name_left = layer.name
            break
            
    if target_layer_name_left is None:
        raise ValueError(f"Unsupported Encoder: Could not find a valid 4D skip connection layer for resolution {res}x{res} inside the left stream encoder.")

    left_skip_tensor = left_encoder.get_layer(target_layer_name_left).output

    # Dynamic Search for the Skip Connection on Right Stream
    target_layer_name_right = None
    
    # Traverse backwards to find the deepest layer at the target resolution
    for layer in right_encoder.layers[::-1]:
        shape = layer.output.shape
        if len(shape) == 4 and shape[1] == res and shape[2] == res:
            target_layer_name_right = layer.name
            break
            
    if target_layer_name_right is None:
        raise ValueError(f"Unsupported Encoder: Could not find a valid 4D skip connection layer for resolution {res}x{res} inside the right stream encoder.")

    right_skip_tensor = right_encoder.get_layer(target_layer_name_right).output
    
    print(f"Linking Skip Connection at {res}x{res}: decoder_{res} + {target_layer_name_left} + {target_layer_name_right}")
    
    # Combining Skip Connection with upscaled map
    x = Concatenate(axis=-1, name=f"skip_concat_{res}")([x, left_skip_tensor, right_skip_tensor])
    
    # Upscaled map refiner
    x = Conv2D(fmap, kernel_size=(3, 3), padding='same', name=f"decoder_refine_{res}")(x) 
    x = BatchNormalization()(x)
    x = Activation('relu')(x)


# --- Stage 4: (Optional) FINAL IMAGE REFINER ---
while fmap > 16:
    fmap = int(fmap / 2)
    x = Conv2D(fmap, kernel_size=(3, 3), padding='same', name=f"opt_refiner_{fmap}")(x) 
    x = BatchNormalization()(x)
    x = Activation('relu')(x)


# Final Output Layer: 1x1 Conv to collapse channels, Sigmoid for 0.0 to 1.0 mapping
fused_output = Conv2D(3, kernel_size=(1, 1), activation='sigmoid', name="fused_output")(x)

# Build and Instantiate the Model
fusion_model = Model(inputs=[input_x1, input_x2], outputs=fused_output, name="FusionNet")
fusion_model.summary()
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1783089597.598568      23 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Linking Skip Connection at 16x16: decoder_16 + pool4_conv_left + pool4_conv_right
# Linking Skip Connection at 32x32: decoder_32 + pool3_conv_left + pool3_conv_right
# Linking Skip Connection at 64x64: decoder_64 + pool2_conv_left + pool2_conv_right
# Linking Skip Connection at 128x128: decoder_128 + conv1_relu_left + conv1_relu_right
# Linking Skip Connection at 256x256: decoder_256 + input_x1 + input_x2
# Model: "FusionNet"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_x1            │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_x2            │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_left │ (None, 262, 262,  │          0 │ input_x1[0][0]    │
# │ (ZeroPadding2D)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_2_r… │ (None, 262, 262,  │          0 │ input_x2[0][0]    │
# │ (ZeroPadding2D)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_conv_left     │ (None, 128, 128,  │      9,408 │ zero_padding2d_l… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_conv_right    │ (None, 128, 128,  │      9,408 │ zero_padding2d_2… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_bn_left       │ (None, 128, 128,  │        256 │ conv1_conv_left[… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_bn_right      │ (None, 128, 128,  │        256 │ conv1_conv_right… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_relu_left     │ (None, 128, 128,  │          0 │ conv1_bn_left[0]… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_relu_right    │ (None, 128, 128,  │          0 │ conv1_bn_right[0… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_1_l… │ (None, 130, 130,  │          0 │ conv1_relu_left[… │
# │ (ZeroPadding2D)     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_3_r… │ (None, 130, 130,  │          0 │ conv1_relu_right… │
# │ (ZeroPadding2D)     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool1_left          │ (None, 64, 64,    │          0 │ zero_padding2d_1… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool1_right         │ (None, 64, 64,    │          0 │ zero_padding2d_3… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_0_bn_… │ (None, 64, 64,    │        256 │ pool1_left[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_0_bn_… │ (None, 64, 64,    │        256 │ pool1_right[0][0] │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_0_rel… │ (None, 64, 64,    │          0 │ conv2_block1_0_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_0_rel… │ (None, 64, 64,    │          0 │ conv2_block1_0_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_con… │ (None, 64, 64,    │      8,192 │ conv2_block1_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_con… │ (None, 64, 64,    │      8,192 │ conv2_block1_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_bn_… │ (None, 64, 64,    │        512 │ conv2_block1_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_bn_… │ (None, 64, 64,    │        512 │ conv2_block1_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_rel… │ (None, 64, 64,    │          0 │ conv2_block1_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_rel… │ (None, 64, 64,    │          0 │ conv2_block1_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_con… │ (None, 64, 64,    │     36,864 │ conv2_block1_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_con… │ (None, 64, 64,    │     36,864 │ conv2_block1_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_conca… │ (None, 64, 64,    │          0 │ pool1_left[0][0], │
# │ (Concatenate)       │ 96)               │            │ conv2_block1_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_conca… │ (None, 64, 64,    │          0 │ pool1_right[0][0… │
# │ (Concatenate)       │ 96)               │            │ conv2_block1_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_0_bn_… │ (None, 64, 64,    │        384 │ conv2_block1_con… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_0_bn_… │ (None, 64, 64,    │        384 │ conv2_block1_con… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_0_rel… │ (None, 64, 64,    │          0 │ conv2_block2_0_b… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_0_rel… │ (None, 64, 64,    │          0 │ conv2_block2_0_b… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_con… │ (None, 64, 64,    │     12,288 │ conv2_block2_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_con… │ (None, 64, 64,    │     12,288 │ conv2_block2_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_bn_… │ (None, 64, 64,    │        512 │ conv2_block2_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_bn_… │ (None, 64, 64,    │        512 │ conv2_block2_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_rel… │ (None, 64, 64,    │          0 │ conv2_block2_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_rel… │ (None, 64, 64,    │          0 │ conv2_block2_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_con… │ (None, 64, 64,    │     36,864 │ conv2_block2_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_con… │ (None, 64, 64,    │     36,864 │ conv2_block2_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_conca… │ (None, 64, 64,    │          0 │ conv2_block1_con… │
# │ (Concatenate)       │ 128)              │            │ conv2_block2_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_conca… │ (None, 64, 64,    │          0 │ conv2_block1_con… │
# │ (Concatenate)       │ 128)              │            │ conv2_block2_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_0_bn_… │ (None, 64, 64,    │        512 │ conv2_block2_con… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_0_bn_… │ (None, 64, 64,    │        512 │ conv2_block2_con… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_0_rel… │ (None, 64, 64,    │          0 │ conv2_block3_0_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_0_rel… │ (None, 64, 64,    │          0 │ conv2_block3_0_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_con… │ (None, 64, 64,    │     16,384 │ conv2_block3_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_con… │ (None, 64, 64,    │     16,384 │ conv2_block3_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_bn_… │ (None, 64, 64,    │        512 │ conv2_block3_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_bn_… │ (None, 64, 64,    │        512 │ conv2_block3_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_rel… │ (None, 64, 64,    │          0 │ conv2_block3_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_rel… │ (None, 64, 64,    │          0 │ conv2_block3_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_con… │ (None, 64, 64,    │     36,864 │ conv2_block3_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_con… │ (None, 64, 64,    │     36,864 │ conv2_block3_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_conca… │ (None, 64, 64,    │          0 │ conv2_block2_con… │
# │ (Concatenate)       │ 160)              │            │ conv2_block3_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_conca… │ (None, 64, 64,    │          0 │ conv2_block2_con… │
# │ (Concatenate)       │ 160)              │            │ conv2_block3_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block4_0_bn_… │ (None, 64, 64,    │        640 │ conv2_block3_con… │
# │ (BatchNormalizatio… │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block4_0_bn_… │ (None, 64, 64,    │        640 │ conv2_block3_con… │
# │ (BatchNormalizatio… │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block4_0_rel… │ (None, 64, 64,    │          0 │ conv2_block4_0_b… │
# │ (Activation)        │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block4_0_rel… │ (None, 64, 64,    │          0 │ conv2_block4_0_b… │
# │ (Activation)        │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block4_1_con… │ (None, 64, 64,    │     20,480 │ conv2_block4_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block4_1_con… │ (None, 64, 64,    │     20,480 │ conv2_block4_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block4_1_bn_… │ (None, 64, 64,    │        512 │ conv2_block4_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block4_1_bn_… │ (None, 64, 64,    │        512 │ conv2_block4_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block4_1_rel… │ (None, 64, 64,    │          0 │ conv2_block4_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block4_1_rel… │ (None, 64, 64,    │          0 │ conv2_block4_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block4_2_con… │ (None, 64, 64,    │     36,864 │ conv2_block4_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block4_2_con… │ (None, 64, 64,    │     36,864 │ conv2_block4_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block4_conca… │ (None, 64, 64,    │          0 │ conv2_block3_con… │
# │ (Concatenate)       │ 192)              │            │ conv2_block4_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block4_conca… │ (None, 64, 64,    │          0 │ conv2_block3_con… │
# │ (Concatenate)       │ 192)              │            │ conv2_block4_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block5_0_bn_… │ (None, 64, 64,    │        768 │ conv2_block4_con… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block5_0_bn_… │ (None, 64, 64,    │        768 │ conv2_block4_con… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block5_0_rel… │ (None, 64, 64,    │          0 │ conv2_block5_0_b… │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block5_0_rel… │ (None, 64, 64,    │          0 │ conv2_block5_0_b… │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block5_1_con… │ (None, 64, 64,    │     24,576 │ conv2_block5_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block5_1_con… │ (None, 64, 64,    │     24,576 │ conv2_block5_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block5_1_bn_… │ (None, 64, 64,    │        512 │ conv2_block5_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block5_1_bn_… │ (None, 64, 64,    │        512 │ conv2_block5_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block5_1_rel… │ (None, 64, 64,    │          0 │ conv2_block5_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block5_1_rel… │ (None, 64, 64,    │          0 │ conv2_block5_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block5_2_con… │ (None, 64, 64,    │     36,864 │ conv2_block5_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block5_2_con… │ (None, 64, 64,    │     36,864 │ conv2_block5_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block5_conca… │ (None, 64, 64,    │          0 │ conv2_block4_con… │
# │ (Concatenate)       │ 224)              │            │ conv2_block5_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block5_conca… │ (None, 64, 64,    │          0 │ conv2_block4_con… │
# │ (Concatenate)       │ 224)              │            │ conv2_block5_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block6_0_bn_… │ (None, 64, 64,    │        896 │ conv2_block5_con… │
# │ (BatchNormalizatio… │ 224)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block6_0_bn_… │ (None, 64, 64,    │        896 │ conv2_block5_con… │
# │ (BatchNormalizatio… │ 224)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block6_0_rel… │ (None, 64, 64,    │          0 │ conv2_block6_0_b… │
# │ (Activation)        │ 224)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block6_0_rel… │ (None, 64, 64,    │          0 │ conv2_block6_0_b… │
# │ (Activation)        │ 224)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block6_1_con… │ (None, 64, 64,    │     28,672 │ conv2_block6_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block6_1_con… │ (None, 64, 64,    │     28,672 │ conv2_block6_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block6_1_bn_… │ (None, 64, 64,    │        512 │ conv2_block6_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block6_1_bn_… │ (None, 64, 64,    │        512 │ conv2_block6_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block6_1_rel… │ (None, 64, 64,    │          0 │ conv2_block6_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block6_1_rel… │ (None, 64, 64,    │          0 │ conv2_block6_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block6_2_con… │ (None, 64, 64,    │     36,864 │ conv2_block6_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block6_2_con… │ (None, 64, 64,    │     36,864 │ conv2_block6_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block6_conca… │ (None, 64, 64,    │          0 │ conv2_block5_con… │
# │ (Concatenate)       │ 256)              │            │ conv2_block6_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block6_conca… │ (None, 64, 64,    │          0 │ conv2_block5_con… │
# │ (Concatenate)       │ 256)              │            │ conv2_block6_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool2_bn_left       │ (None, 64, 64,    │      1,024 │ conv2_block6_con… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool2_bn_right      │ (None, 64, 64,    │      1,024 │ conv2_block6_con… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool2_relu_left     │ (None, 64, 64,    │          0 │ pool2_bn_left[0]… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool2_relu_right    │ (None, 64, 64,    │          0 │ pool2_bn_right[0… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool2_conv_left     │ (None, 64, 64,    │     32,768 │ pool2_relu_left[… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool2_conv_right    │ (None, 64, 64,    │     32,768 │ pool2_relu_right… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool2_pool_left     │ (None, 32, 32,    │          0 │ pool2_conv_left[… │
# │ (AveragePooling2D)  │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool2_pool_right    │ (None, 32, 32,    │          0 │ pool2_conv_right… │
# │ (AveragePooling2D)  │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_0_bn_… │ (None, 32, 32,    │        512 │ pool2_pool_left[… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_0_bn_… │ (None, 32, 32,    │        512 │ pool2_pool_right… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_0_rel… │ (None, 32, 32,    │          0 │ conv3_block1_0_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_0_rel… │ (None, 32, 32,    │          0 │ conv3_block1_0_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_con… │ (None, 32, 32,    │     16,384 │ conv3_block1_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_con… │ (None, 32, 32,    │     16,384 │ conv3_block1_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_bn_… │ (None, 32, 32,    │        512 │ conv3_block1_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_bn_… │ (None, 32, 32,    │        512 │ conv3_block1_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_rel… │ (None, 32, 32,    │          0 │ conv3_block1_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_rel… │ (None, 32, 32,    │          0 │ conv3_block1_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_con… │ (None, 32, 32,    │     36,864 │ conv3_block1_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_con… │ (None, 32, 32,    │     36,864 │ conv3_block1_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_conca… │ (None, 32, 32,    │          0 │ pool2_pool_left[… │
# │ (Concatenate)       │ 160)              │            │ conv3_block1_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_conca… │ (None, 32, 32,    │          0 │ pool2_pool_right… │
# │ (Concatenate)       │ 160)              │            │ conv3_block1_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_0_bn_… │ (None, 32, 32,    │        640 │ conv3_block1_con… │
# │ (BatchNormalizatio… │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_0_bn_… │ (None, 32, 32,    │        640 │ conv3_block1_con… │
# │ (BatchNormalizatio… │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_0_rel… │ (None, 32, 32,    │          0 │ conv3_block2_0_b… │
# │ (Activation)        │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_0_rel… │ (None, 32, 32,    │          0 │ conv3_block2_0_b… │
# │ (Activation)        │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_con… │ (None, 32, 32,    │     20,480 │ conv3_block2_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_con… │ (None, 32, 32,    │     20,480 │ conv3_block2_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_bn_… │ (None, 32, 32,    │        512 │ conv3_block2_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_bn_… │ (None, 32, 32,    │        512 │ conv3_block2_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_rel… │ (None, 32, 32,    │          0 │ conv3_block2_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_rel… │ (None, 32, 32,    │          0 │ conv3_block2_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_con… │ (None, 32, 32,    │     36,864 │ conv3_block2_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_con… │ (None, 32, 32,    │     36,864 │ conv3_block2_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_conca… │ (None, 32, 32,    │          0 │ conv3_block1_con… │
# │ (Concatenate)       │ 192)              │            │ conv3_block2_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_conca… │ (None, 32, 32,    │          0 │ conv3_block1_con… │
# │ (Concatenate)       │ 192)              │            │ conv3_block2_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_0_bn_… │ (None, 32, 32,    │        768 │ conv3_block2_con… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_0_bn_… │ (None, 32, 32,    │        768 │ conv3_block2_con… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_0_rel… │ (None, 32, 32,    │          0 │ conv3_block3_0_b… │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_0_rel… │ (None, 32, 32,    │          0 │ conv3_block3_0_b… │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_con… │ (None, 32, 32,    │     24,576 │ conv3_block3_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_con… │ (None, 32, 32,    │     24,576 │ conv3_block3_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_bn_… │ (None, 32, 32,    │        512 │ conv3_block3_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_bn_… │ (None, 32, 32,    │        512 │ conv3_block3_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_rel… │ (None, 32, 32,    │          0 │ conv3_block3_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_rel… │ (None, 32, 32,    │          0 │ conv3_block3_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_con… │ (None, 32, 32,    │     36,864 │ conv3_block3_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_con… │ (None, 32, 32,    │     36,864 │ conv3_block3_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_conca… │ (None, 32, 32,    │          0 │ conv3_block2_con… │
# │ (Concatenate)       │ 224)              │            │ conv3_block3_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_conca… │ (None, 32, 32,    │          0 │ conv3_block2_con… │
# │ (Concatenate)       │ 224)              │            │ conv3_block3_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_0_bn_… │ (None, 32, 32,    │        896 │ conv3_block3_con… │
# │ (BatchNormalizatio… │ 224)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_0_bn_… │ (None, 32, 32,    │        896 │ conv3_block3_con… │
# │ (BatchNormalizatio… │ 224)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_0_rel… │ (None, 32, 32,    │          0 │ conv3_block4_0_b… │
# │ (Activation)        │ 224)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_0_rel… │ (None, 32, 32,    │          0 │ conv3_block4_0_b… │
# │ (Activation)        │ 224)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_con… │ (None, 32, 32,    │     28,672 │ conv3_block4_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_con… │ (None, 32, 32,    │     28,672 │ conv3_block4_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_bn_… │ (None, 32, 32,    │        512 │ conv3_block4_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_bn_… │ (None, 32, 32,    │        512 │ conv3_block4_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_rel… │ (None, 32, 32,    │          0 │ conv3_block4_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_rel… │ (None, 32, 32,    │          0 │ conv3_block4_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_con… │ (None, 32, 32,    │     36,864 │ conv3_block4_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_con… │ (None, 32, 32,    │     36,864 │ conv3_block4_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_conca… │ (None, 32, 32,    │          0 │ conv3_block3_con… │
# │ (Concatenate)       │ 256)              │            │ conv3_block4_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_conca… │ (None, 32, 32,    │          0 │ conv3_block3_con… │
# │ (Concatenate)       │ 256)              │            │ conv3_block4_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block5_0_bn_… │ (None, 32, 32,    │      1,024 │ conv3_block4_con… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block5_0_bn_… │ (None, 32, 32,    │      1,024 │ conv3_block4_con… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block5_0_rel… │ (None, 32, 32,    │          0 │ conv3_block5_0_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block5_0_rel… │ (None, 32, 32,    │          0 │ conv3_block5_0_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block5_1_con… │ (None, 32, 32,    │     32,768 │ conv3_block5_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block5_1_con… │ (None, 32, 32,    │     32,768 │ conv3_block5_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block5_1_bn_… │ (None, 32, 32,    │        512 │ conv3_block5_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block5_1_bn_… │ (None, 32, 32,    │        512 │ conv3_block5_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block5_1_rel… │ (None, 32, 32,    │          0 │ conv3_block5_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block5_1_rel… │ (None, 32, 32,    │          0 │ conv3_block5_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block5_2_con… │ (None, 32, 32,    │     36,864 │ conv3_block5_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block5_2_con… │ (None, 32, 32,    │     36,864 │ conv3_block5_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block5_conca… │ (None, 32, 32,    │          0 │ conv3_block4_con… │
# │ (Concatenate)       │ 288)              │            │ conv3_block5_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block5_conca… │ (None, 32, 32,    │          0 │ conv3_block4_con… │
# │ (Concatenate)       │ 288)              │            │ conv3_block5_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block6_0_bn_… │ (None, 32, 32,    │      1,152 │ conv3_block5_con… │
# │ (BatchNormalizatio… │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block6_0_bn_… │ (None, 32, 32,    │      1,152 │ conv3_block5_con… │
# │ (BatchNormalizatio… │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block6_0_rel… │ (None, 32, 32,    │          0 │ conv3_block6_0_b… │
# │ (Activation)        │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block6_0_rel… │ (None, 32, 32,    │          0 │ conv3_block6_0_b… │
# │ (Activation)        │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block6_1_con… │ (None, 32, 32,    │     36,864 │ conv3_block6_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block6_1_con… │ (None, 32, 32,    │     36,864 │ conv3_block6_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block6_1_bn_… │ (None, 32, 32,    │        512 │ conv3_block6_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block6_1_bn_… │ (None, 32, 32,    │        512 │ conv3_block6_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block6_1_rel… │ (None, 32, 32,    │          0 │ conv3_block6_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block6_1_rel… │ (None, 32, 32,    │          0 │ conv3_block6_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block6_2_con… │ (None, 32, 32,    │     36,864 │ conv3_block6_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block6_2_con… │ (None, 32, 32,    │     36,864 │ conv3_block6_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block6_conca… │ (None, 32, 32,    │          0 │ conv3_block5_con… │
# │ (Concatenate)       │ 320)              │            │ conv3_block6_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block6_conca… │ (None, 32, 32,    │          0 │ conv3_block5_con… │
# │ (Concatenate)       │ 320)              │            │ conv3_block6_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block7_0_bn_… │ (None, 32, 32,    │      1,280 │ conv3_block6_con… │
# │ (BatchNormalizatio… │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block7_0_bn_… │ (None, 32, 32,    │      1,280 │ conv3_block6_con… │
# │ (BatchNormalizatio… │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block7_0_rel… │ (None, 32, 32,    │          0 │ conv3_block7_0_b… │
# │ (Activation)        │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block7_0_rel… │ (None, 32, 32,    │          0 │ conv3_block7_0_b… │
# │ (Activation)        │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block7_1_con… │ (None, 32, 32,    │     40,960 │ conv3_block7_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block7_1_con… │ (None, 32, 32,    │     40,960 │ conv3_block7_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block7_1_bn_… │ (None, 32, 32,    │        512 │ conv3_block7_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block7_1_bn_… │ (None, 32, 32,    │        512 │ conv3_block7_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block7_1_rel… │ (None, 32, 32,    │          0 │ conv3_block7_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block7_1_rel… │ (None, 32, 32,    │          0 │ conv3_block7_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block7_2_con… │ (None, 32, 32,    │     36,864 │ conv3_block7_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block7_2_con… │ (None, 32, 32,    │     36,864 │ conv3_block7_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block7_conca… │ (None, 32, 32,    │          0 │ conv3_block6_con… │
# │ (Concatenate)       │ 352)              │            │ conv3_block7_2_c… │
# ...
# │ conv5_block15_0_bn… │ (None, 8, 8, 960) │      3,840 │ conv5_block14_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block15_0_re… │ (None, 8, 8, 960) │          0 │ conv5_block15_0_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block15_0_re… │ (None, 8, 8, 960) │          0 │ conv5_block15_0_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block15_1_co… │ (None, 8, 8, 128) │    122,880 │ conv5_block15_0_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block15_1_co… │ (None, 8, 8, 128) │    122,880 │ conv5_block15_0_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block15_1_bn… │ (None, 8, 8, 128) │        512 │ conv5_block15_1_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block15_1_bn… │ (None, 8, 8, 128) │        512 │ conv5_block15_1_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block15_1_re… │ (None, 8, 8, 128) │          0 │ conv5_block15_1_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block15_1_re… │ (None, 8, 8, 128) │          0 │ conv5_block15_1_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block15_2_co… │ (None, 8, 8, 32)  │     36,864 │ conv5_block15_1_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block15_2_co… │ (None, 8, 8, 32)  │     36,864 │ conv5_block15_1_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block15_conc… │ (None, 8, 8, 992) │          0 │ conv5_block14_co… │
# │ (Concatenate)       │                   │            │ conv5_block15_2_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block15_conc… │ (None, 8, 8, 992) │          0 │ conv5_block14_co… │
# │ (Concatenate)       │                   │            │ conv5_block15_2_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block16_0_bn… │ (None, 8, 8, 992) │      3,968 │ conv5_block15_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block16_0_bn… │ (None, 8, 8, 992) │      3,968 │ conv5_block15_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block16_0_re… │ (None, 8, 8, 992) │          0 │ conv5_block16_0_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block16_0_re… │ (None, 8, 8, 992) │          0 │ conv5_block16_0_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block16_1_co… │ (None, 8, 8, 128) │    126,976 │ conv5_block16_0_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block16_1_co… │ (None, 8, 8, 128) │    126,976 │ conv5_block16_0_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block16_1_bn… │ (None, 8, 8, 128) │        512 │ conv5_block16_1_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block16_1_bn… │ (None, 8, 8, 128) │        512 │ conv5_block16_1_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block16_1_re… │ (None, 8, 8, 128) │          0 │ conv5_block16_1_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block16_1_re… │ (None, 8, 8, 128) │          0 │ conv5_block16_1_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block16_2_co… │ (None, 8, 8, 32)  │     36,864 │ conv5_block16_1_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block16_2_co… │ (None, 8, 8, 32)  │     36,864 │ conv5_block16_1_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block16_conc… │ (None, 8, 8,      │          0 │ conv5_block15_co… │
# │ (Concatenate)       │ 1024)             │            │ conv5_block16_2_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block16_conc… │ (None, 8, 8,      │          0 │ conv5_block15_co… │
# │ (Concatenate)       │ 1024)             │            │ conv5_block16_2_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn_left             │ (None, 8, 8,      │      4,096 │ conv5_block16_co… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn_right            │ (None, 8, 8,      │      4,096 │ conv5_block16_co… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ relu_left           │ (None, 8, 8,      │          0 │ bn_left[0][0]     │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ relu_right          │ (None, 8, 8,      │          0 │ bn_right[0][0]    │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ feature_map_combine │ (None, 8, 8,      │          0 │ relu_left[0][0],  │
# │ (Concatenate)       │ 2048)             │            │ relu_right[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ feature_map_refiner │ (None, 8, 8,      │ 37,750,784 │ feature_map_comb… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 8, 8,      │      8,192 │ feature_map_refi… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 8, 8,      │          0 │ batch_normalizat… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_16          │ (None, 16, 16,    │ 18,875,392 │ activation[0][0]  │
# │ (Conv2DTranspose)   │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ skip_concat_16      │ (None, 16, 16,    │          0 │ decoder_16[0][0], │
# │ (Concatenate)       │ 2048)             │            │ pool4_conv_left[… │
# │                     │                   │            │ pool4_conv_right… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_refine_16   │ (None, 16, 16,    │ 18,875,392 │ skip_concat_16[0… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      4,096 │ decoder_refine_1… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_32          │ (None, 32, 32,    │  4,719,104 │ activation_1[0][… │
# │ (Conv2DTranspose)   │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ skip_concat_32      │ (None, 32, 32,    │          0 │ decoder_32[0][0], │
# │ (Concatenate)       │ 1024)             │            │ pool3_conv_left[… │
# │                     │                   │            │ pool3_conv_right… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_refine_32   │ (None, 32, 32,    │  4,719,104 │ skip_concat_32[0… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      2,048 │ decoder_refine_3… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_64          │ (None, 64, 64,    │  1,179,904 │ activation_2[0][… │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ skip_concat_64      │ (None, 64, 64,    │          0 │ decoder_64[0][0], │
# │ (Concatenate)       │ 512)              │            │ pool2_conv_left[… │
# │                     │                   │            │ pool2_conv_right… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_refine_64   │ (None, 64, 64,    │  1,179,904 │ skip_concat_64[0… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │      1,024 │ decoder_refine_6… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_128         │ (None, 128, 128,  │    295,040 │ activation_3[0][… │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ skip_concat_128     │ (None, 128, 128,  │          0 │ decoder_128[0][0… │
# │ (Concatenate)       │ 256)              │            │ conv1_relu_left[… │
# │                     │                   │            │ conv1_relu_right… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_refine_128  │ (None, 128, 128,  │    295,040 │ skip_concat_128[… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        512 │ decoder_refine_1… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_256         │ (None, 256, 256,  │     73,792 │ activation_4[0][… │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ skip_concat_256     │ (None, 256, 256,  │          0 │ decoder_256[0][0… │
# │ (Concatenate)       │ 70)               │            │ input_x1[0][0],   │
# │                     │                   │            │ input_x2[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_refine_256  │ (None, 256, 256,  │     40,384 │ skip_concat_256[… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        256 │ decoder_refine_2… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ opt_refiner_32      │ (None, 256, 256,  │     18,464 │ activation_5[0][… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        128 │ opt_refiner_32[0… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ opt_refiner_16      │ (None, 256, 256,  │      4,624 │ activation_6[0][… │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ opt_refiner_16[0… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fused_output        │ (None, 256, 256,  │         51 │ activation_7[0][… │
# │ (Conv2D)            │ 3)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 102,118,307 (389.55 MB)
#  Trainable params: 101,942,851 (388.88 MB)
#  Non-trainable params: 175,456 (685.38 KB)

# %% [markdown]
# ### Loss Function and Evaluation Metrics

# %%
import tensorflow as tf
import numpy as np

def fusion_loss(y_true, y_pred):
    """
    Computes: RGB L1_Loss + 0.5 * Luminance_Edge_Loss
    """
    # 1. Base L1 Loss (Color + Structure)
    # Applies to all 3 RGB channels to guarantee pixel-perfect color reconstruction
    l1_loss = tf.reduce_mean(tf.abs(y_true - y_pred))
    
    # 2. Isolate Structure for Edge Detection
    # tf.image.rgb_to_grayscale mathematically extracts the Y (Luminance) channel.
    # Shape converts from [batch, h, w, 3] to [batch, h, w, 1]
    y_true_luma = tf.image.rgb_to_grayscale(y_true)
    y_pred_luma = tf.image.rgb_to_grayscale(y_pred)
    
    # 3. Edge Loss using Sobel Filters strictly on the Luminance channel
    # This prevents the network from hallucinating edge artifacts inside the smooth PET thermal clouds
    sobel_true = tf.image.sobel_edges(y_true_luma)
    sobel_pred = tf.image.sobel_edges(y_pred_luma)
    
    edge_loss = tf.reduce_mean(tf.abs(sobel_true - sobel_pred))
    
    # 4. Combine them
    total_loss = l1_loss + (0.5 * edge_loss)
    
    return total_loss
    

# 1. PSNR (Peak Signal-to-Noise Ratio)
def psnr(y_true, y_pred):
    return tf.image.psnr(y_true, y_pred, max_val=1.0)

# 2. SSIM (Structural Similarity Index Measure)
def ssim(y_true, y_pred):
    return tf.image.ssim(y_true, y_pred, max_val=1.0)

# 3. Mutual Information (MI)
def numpy_mutual_information(y_true, y_pred):
    """
    Standard numpy implementation of Mutual Information using a 2D joint histogram.
    """
    # It converts the entire RGB matrix into a continuous 1D distribution array.
    y_true_flat = y_true.flatten()
    y_pred_flat = y_pred.flatten()
    
    # Calculate the 2D histogram (using 100 bins for continuous 0.0-1.0 values)
    hist_2d, _, _ = np.histogram2d(y_true_flat, y_pred_flat, bins=100)
    
    # Convert histogram counts to probabilities
    pxy = hist_2d / float(np.sum(hist_2d))
    px = np.sum(pxy, axis=1)
    py = np.sum(pxy, axis=0)
    px_py = px[:, None] * py[None, :]
    
    # Calculate MI only where probabilities are non-zero to avoid log(0)
    non_zeros = pxy > 0
    mi = np.sum(pxy[non_zeros] * np.log(pxy[non_zeros] / px_py[non_zeros]))
    
    return np.float32(mi)

# %% [markdown]
# ## Warm Up Training

# %% [markdown]
# ### Model Compilation

# %%
from tensorflow.keras.optimizers import Adam

# Freezing Encoder
left_encoder.trainable = False
right_encoder.trainable = False

# Compile the model
fusion_model.compile(
    optimizer=Adam(learning_rate=1e-3),
    loss=fusion_loss,
    metrics=[psnr]
)

# %% [markdown]
# ### Callbacks

# %%
from tensorflow.keras.callbacks import EarlyStopping

# Stops the training if the monitor metrics doesnt improves in specific patience epochs
early_stopping = EarlyStopping(monitor='val_loss', patience=10, min_delta=1e-3, restore_best_weights=True)

# %% [markdown]
# ### Training

# %%
train_steps = len(X1_train) // batch_size

print(f"Batch Size: {batch_size}")
print(f"Calculated Train Steps: {train_steps}")
print('')

print("Starting Warm Up...")
history_warmup = fusion_model.fit(
    train_fusion_gen,
    steps_per_epoch=train_steps,
    epochs=100,
    validation_data=([X1_val, X2_val], y_val),
    callbacks=[early_stopping]
)
# Out:
# Batch Size: 4
# Calculated Train Steps: 32
#
# Starting Warm Up...
# Epoch 1/100
#  1/32 ━━━━━━━━━━━━━━━━━━━━ 33:07 64s/step - loss: 0.5622 - psnr: 7.3116
# I0000 00:00:1783089668.912232      71 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 105s 1s/step - loss: 0.2931 - psnr: 11.3745 - val_loss: 0.6742 - val_psnr: 4.2933
# Epoch 2/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 202ms/step - loss: 0.1818 - psnr: 14.9282 - val_loss: 0.3271 - val_psnr: 11.7155
# Epoch 3/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 198ms/step - loss: 0.1349 - psnr: 17.3590 - val_loss: 0.1715 - val_psnr: 16.6033
# Epoch 4/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 176ms/step - loss: 0.1054 - psnr: 19.5797 - val_loss: 0.1670 - val_psnr: 16.4025
# Epoch 5/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 176ms/step - loss: 0.0834 - psnr: 21.7685 - val_loss: 0.1062 - val_psnr: 20.1873
# Epoch 6/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 179ms/step - loss: 0.0686 - psnr: 23.6976 - val_loss: 0.0755 - val_psnr: 23.3905
# Epoch 7/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 150ms/step - loss: 0.0579 - psnr: 25.3844 - val_loss: 0.0841 - val_psnr: 22.0514
# Epoch 8/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 199ms/step - loss: 0.0499 - psnr: 26.8615 - val_loss: 0.0577 - val_psnr: 25.3956
# Epoch 9/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 180ms/step - loss: 0.0451 - psnr: 27.9327 - val_loss: 0.0555 - val_psnr: 25.6432
# Epoch 10/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 172ms/step - loss: 0.0406 - psnr: 28.8779 - val_loss: 0.0508 - val_psnr: 25.7680
# Epoch 11/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.0387 - psnr: 29.3040 - val_loss: 0.0459 - val_psnr: 27.1678
# Epoch 12/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 178ms/step - loss: 0.0342 - psnr: 30.5223 - val_loss: 0.0426 - val_psnr: 27.2314
# Epoch 13/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 172ms/step - loss: 0.0312 - psnr: 31.2237 - val_loss: 0.0354 - val_psnr: 29.4549
# Epoch 14/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 177ms/step - loss: 0.0300 - psnr: 31.5436 - val_loss: 0.0325 - val_psnr: 29.9963
# Epoch 15/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 143ms/step - loss: 0.0298 - psnr: 31.5399 - val_loss: 0.0371 - val_psnr: 28.2990
# Epoch 16/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 195ms/step - loss: 0.0282 - psnr: 32.0767 - val_loss: 0.0285 - val_psnr: 31.1501
# Epoch 17/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 149ms/step - loss: 0.0262 - psnr: 32.7263 - val_loss: 0.0297 - val_psnr: 30.5764
# Epoch 18/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 188ms/step - loss: 0.0244 - psnr: 33.2004 - val_loss: 0.0273 - val_psnr: 31.6013
# Epoch 19/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 181ms/step - loss: 0.0243 - psnr: 33.1607 - val_loss: 0.0246 - val_psnr: 32.7118
# Epoch 20/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 153ms/step - loss: 0.0234 - psnr: 33.5238 - val_loss: 0.0347 - val_psnr: 29.0403
# Epoch 21/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 168ms/step - loss: 0.0231 - psnr: 33.7809 - val_loss: 0.0269 - val_psnr: 31.7591
# Epoch 22/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 169ms/step - loss: 0.0235 - psnr: 33.4706 - val_loss: 0.0261 - val_psnr: 31.5370
# Epoch 23/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 166ms/step - loss: 0.0217 - psnr: 34.3440 - val_loss: 0.0245 - val_psnr: 32.1657
# Epoch 24/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 189ms/step - loss: 0.0214 - psnr: 34.2082 - val_loss: 0.0217 - val_psnr: 33.6253
# Epoch 25/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 149ms/step - loss: 0.0212 - psnr: 34.3752 - val_loss: 0.0245 - val_psnr: 32.2283
# Epoch 26/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 166ms/step - loss: 0.0214 - psnr: 34.2201 - val_loss: 0.0274 - val_psnr: 31.0583
# Epoch 27/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 164ms/step - loss: 0.0200 - psnr: 34.7580 - val_loss: 0.0278 - val_psnr: 30.5209
# Epoch 28/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 188ms/step - loss: 0.0195 - psnr: 34.8214 - val_loss: 0.0195 - val_psnr: 34.5582
# Epoch 29/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 155ms/step - loss: 0.0198 - psnr: 34.7591 - val_loss: 0.0223 - val_psnr: 33.1288
# Epoch 30/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 168ms/step - loss: 0.0195 - psnr: 34.9377 - val_loss: 0.0210 - val_psnr: 33.7792
# Epoch 31/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 170ms/step - loss: 0.0200 - psnr: 34.8841 - val_loss: 0.0189 - val_psnr: 34.8769
# Epoch 32/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 175ms/step - loss: 0.0185 - psnr: 35.4466 - val_loss: 0.0233 - val_psnr: 32.6674
# Epoch 33/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 199ms/step - loss: 0.0177 - psnr: 35.8475 - val_loss: 0.0163 - val_psnr: 35.9984
# Epoch 34/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 146ms/step - loss: 0.0176 - psnr: 35.6804 - val_loss: 0.0195 - val_psnr: 34.2818
# Epoch 35/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 163ms/step - loss: 0.0162 - psnr: 36.6427 - val_loss: 0.0178 - val_psnr: 34.8974
# Epoch 36/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 167ms/step - loss: 0.0179 - psnr: 35.3856 - val_loss: 0.0223 - val_psnr: 32.3036
# Epoch 37/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 161ms/step - loss: 0.0174 - psnr: 35.7830 - val_loss: 0.0233 - val_psnr: 32.6586
# Epoch 38/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 159ms/step - loss: 0.0174 - psnr: 35.6193 - val_loss: 0.0227 - val_psnr: 32.9424
# Epoch 39/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 164ms/step - loss: 0.0179 - psnr: 35.6335 - val_loss: 0.0172 - val_psnr: 35.3525
# Epoch 40/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 199ms/step - loss: 0.0162 - psnr: 36.3067 - val_loss: 0.0150 - val_psnr: 36.6188
# Epoch 41/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 145ms/step - loss: 0.0151 - psnr: 37.0056 - val_loss: 0.0163 - val_psnr: 35.8303
# Epoch 42/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 165ms/step - loss: 0.0159 - psnr: 36.7423 - val_loss: 0.0490 - val_psnr: 25.2024
# Epoch 43/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 162ms/step - loss: 0.0165 - psnr: 36.1380 - val_loss: 0.0185 - val_psnr: 34.4606
# Epoch 44/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 169ms/step - loss: 0.0156 - psnr: 36.8800 - val_loss: 0.0183 - val_psnr: 35.0419
# Epoch 45/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 165ms/step - loss: 0.0170 - psnr: 35.6736 - val_loss: 0.0191 - val_psnr: 34.7124
# Epoch 46/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 169ms/step - loss: 0.0163 - psnr: 36.3665 - val_loss: 0.0193 - val_psnr: 34.4794
# Epoch 47/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 164ms/step - loss: 0.0163 - psnr: 36.0155 - val_loss: 0.0221 - val_psnr: 33.0648
# Epoch 48/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 164ms/step - loss: 0.0157 - psnr: 36.5719 - val_loss: 0.0210 - val_psnr: 33.5096
# Epoch 49/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 179ms/step - loss: 0.0154 - psnr: 36.7989 - val_loss: 0.0213 - val_psnr: 33.1196
# Epoch 50/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 164ms/step - loss: 0.0172 - psnr: 35.4079 - val_loss: 0.0200 - val_psnr: 33.8991

# %% [markdown]
# ## Fine Tuning

# %% [markdown]
# ### Model Compilation

# %%
from tensorflow.keras.optimizers import Adam

# Define how much last layers will be fine-tuned
percent_of_layers_to_train = 25
to_be_trained_left = int((percent_of_layers_to_train/100)*len(left_encoder.layers))
to_be_trained_right = int((percent_of_layers_to_train/100)*len(right_encoder.layers))

print(f"Trainable Layers for Left Stream : {to_be_trained_left}")
print(f"Trainable Layers for Right Stream : {to_be_trained_right}")

for layer in left_encoder.layers[:-to_be_trained_left]:
    layer.trainable = False

for layer in left_encoder.layers[-to_be_trained_left:]:
    layer.trainable = True

for layer in right_encoder.layers[:-to_be_trained_right]:
    layer.trainable = False

for layer in right_encoder.layers[-to_be_trained_right:]:
    layer.trainable = True


# Compile the model
fusion_model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss=fusion_loss,
    metrics=[psnr]
)
# Out:
# Trainable Layers for Left Stream : 106
# Trainable Layers for Right Stream : 106

# %% [markdown]
# ### Callbacks

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping

# Saves the model automatically whenever the validation loss hits a new all-time low
model_checkpoint = ModelCheckpoint(filepath='/kaggle/working/fusion_model_best.keras', monitor='val_loss', save_best_only=True, mode='min', verbose=0)

# Reduces the learning rate by multiplying with the defined factor if the monitor metrics doesnt improves in specific patience epochs
lr_schedule = ReduceLROnPlateau(monitor='val_loss', factor=0.75, patience=5, min_lr=1e-6)

# Stops the training if the monitor metrics doesnt improves in specific patience epochs
early_stopping = EarlyStopping(monitor='val_loss', patience=30, min_delta=1e-4, restore_best_weights=True)

# %% [markdown]
# ### Training

# %%
# Calculate Steps
train_steps = len(X1_train) // batch_size

print(f"Batch Size: {batch_size}")
print(f"Calculated Train Steps: {train_steps}")
print('')

# The Training Loop
print("Starting Fine Tunning...")
history_finetune = fusion_model.fit(
    train_fusion_gen,
    steps_per_epoch=train_steps,
    epochs=500,
    validation_data=([X1_val, X2_val], y_val),
    callbacks=[model_checkpoint, lr_schedule, early_stopping]
)
# Out:
# Batch Size: 4
# Calculated Train Steps: 32
#
# Starting Fine Tunning...
# Epoch 1/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - loss: 0.0139 - psnr: 37.8953 - val_loss: 0.0146 - val_psnr: 36.7498 - learning_rate: 1.0000e-04
# Epoch 2/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 437ms/step - loss: 0.0143 - psnr: 37.2492 - val_loss: 0.0144 - val_psnr: 37.0473 - learning_rate: 1.0000e-04
# Epoch 3/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 180ms/step - loss: 0.0148 - psnr: 37.4442 - val_loss: 0.0163 - val_psnr: 35.6950 - learning_rate: 1.0000e-04
# Epoch 4/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 472ms/step - loss: 0.0139 - psnr: 37.8995 - val_loss: 0.0141 - val_psnr: 37.1318 - learning_rate: 1.0000e-04
# Epoch 5/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 426ms/step - loss: 0.0139 - psnr: 37.6917 - val_loss: 0.0138 - val_psnr: 37.3505 - learning_rate: 1.0000e-04
# Epoch 6/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 439ms/step - loss: 0.0142 - psnr: 37.3775 - val_loss: 0.0134 - val_psnr: 37.7184 - learning_rate: 1.0000e-04
# Epoch 7/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 427ms/step - loss: 0.0135 - psnr: 37.8802 - val_loss: 0.0128 - val_psnr: 38.0944 - learning_rate: 1.0000e-04
# Epoch 8/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 160ms/step - loss: 0.0128 - psnr: 38.2810 - val_loss: 0.0136 - val_psnr: 37.9393 - learning_rate: 1.0000e-04
# Epoch 9/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 158ms/step - loss: 0.0142 - psnr: 37.4007 - val_loss: 0.0135 - val_psnr: 37.8266 - learning_rate: 1.0000e-04
# Epoch 10/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 423ms/step - loss: 0.0133 - psnr: 38.2390 - val_loss: 0.0127 - val_psnr: 38.0833 - learning_rate: 1.0000e-04
# Epoch 11/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 160ms/step - loss: 0.0131 - psnr: 38.2212 - val_loss: 0.0130 - val_psnr: 38.1084 - learning_rate: 1.0000e-04
# Epoch 12/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 159ms/step - loss: 0.0134 - psnr: 37.9014 - val_loss: 0.0145 - val_psnr: 36.8697 - learning_rate: 1.0000e-04
# Epoch 13/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 428ms/step - loss: 0.0148 - psnr: 37.1460 - val_loss: 0.0123 - val_psnr: 38.4734 - learning_rate: 1.0000e-04
# Epoch 14/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 159ms/step - loss: 0.0136 - psnr: 37.7781 - val_loss: 0.0126 - val_psnr: 37.9545 - learning_rate: 1.0000e-04
# Epoch 15/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 160ms/step - loss: 0.0135 - psnr: 37.7515 - val_loss: 0.0132 - val_psnr: 37.6901 - learning_rate: 1.0000e-04
# Epoch 16/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 157ms/step - loss: 0.0135 - psnr: 38.0395 - val_loss: 0.0130 - val_psnr: 38.1522 - learning_rate: 1.0000e-04
# Epoch 17/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 157ms/step - loss: 0.0118 - psnr: 39.0005 - val_loss: 0.0141 - val_psnr: 37.7395 - learning_rate: 1.0000e-04
# Epoch 18/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 157ms/step - loss: 0.0133 - psnr: 38.0290 - val_loss: 0.0127 - val_psnr: 38.3785 - learning_rate: 1.0000e-04
# Epoch 19/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 157ms/step - loss: 0.0125 - psnr: 38.4305 - val_loss: 0.0125 - val_psnr: 38.2046 - learning_rate: 7.5000e-05
# Epoch 20/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 157ms/step - loss: 0.0116 - psnr: 39.2210 - val_loss: 0.0129 - val_psnr: 37.8007 - learning_rate: 7.5000e-05
# Epoch 21/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 436ms/step - loss: 0.0139 - psnr: 37.6450 - val_loss: 0.0115 - val_psnr: 38.6401 - learning_rate: 7.5000e-05
# Epoch 22/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 159ms/step - loss: 0.0121 - psnr: 38.8190 - val_loss: 0.0118 - val_psnr: 38.5145 - learning_rate: 7.5000e-05
# Epoch 23/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 159ms/step - loss: 0.0127 - psnr: 38.1926 - val_loss: 0.0124 - val_psnr: 38.3463 - learning_rate: 7.5000e-05
# Epoch 24/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 157ms/step - loss: 0.0131 - psnr: 37.9828 - val_loss: 0.0118 - val_psnr: 38.5562 - learning_rate: 7.5000e-05
# Epoch 25/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 158ms/step - loss: 0.0127 - psnr: 38.2220 - val_loss: 0.0121 - val_psnr: 38.4797 - learning_rate: 7.5000e-05
# Epoch 26/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 158ms/step - loss: 0.0129 - psnr: 38.2319 - val_loss: 0.0116 - val_psnr: 38.6328 - learning_rate: 7.5000e-05
# Epoch 27/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 158ms/step - loss: 0.0123 - psnr: 38.5365 - val_loss: 0.0121 - val_psnr: 38.3438 - learning_rate: 5.6250e-05
# Epoch 28/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 158ms/step - loss: 0.0116 - psnr: 39.2182 - val_loss: 0.0115 - val_psnr: 38.5757 - learning_rate: 5.6250e-05
# Epoch 29/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 158ms/step - loss: 0.0127 - psnr: 38.4178 - val_loss: 0.0123 - val_psnr: 38.0520 - learning_rate: 5.6250e-05
# Epoch 30/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 158ms/step - loss: 0.0126 - psnr: 38.4021 - val_loss: 0.0123 - val_psnr: 38.2565 - learning_rate: 5.6250e-05
# Epoch 31/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 402ms/step - loss: 0.0124 - psnr: 38.4734 - val_loss: 0.0115 - val_psnr: 38.6361 - learning_rate: 5.6250e-05
# Epoch 32/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 430ms/step - loss: 0.0119 - psnr: 38.9627 - val_loss: 0.0114 - val_psnr: 38.6049 - learning_rate: 4.2188e-05
# Epoch 33/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 158ms/step - loss: 0.0116 - psnr: 39.2156 - val_loss: 0.0117 - val_psnr: 38.5527 - learning_rate: 4.2188e-05
# Epoch 34/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 399ms/step - loss: 0.0119 - psnr: 38.9271 - val_loss: 0.0114 - val_psnr: 38.7139 - learning_rate: 4.2188e-05
# Epoch 35/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 158ms/step - loss: 0.0119 - psnr: 38.9428 - val_loss: 0.0114 - val_psnr: 38.7334 - learning_rate: 4.2188e-05
# Epoch 36/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 399ms/step - loss: 0.0128 - psnr: 38.1859 - val_loss: 0.0113 - val_psnr: 38.6638 - learning_rate: 4.2188e-05
# Epoch 37/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 161ms/step - loss: 0.0117 - psnr: 38.9829 - val_loss: 0.0114 - val_psnr: 38.7401 - learning_rate: 4.2188e-05
# Epoch 38/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 424ms/step - loss: 0.0116 - psnr: 39.2588 - val_loss: 0.0113 - val_psnr: 38.7547 - learning_rate: 3.1641e-05
# Epoch 39/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 454ms/step - loss: 0.0118 - psnr: 39.1254 - val_loss: 0.0111 - val_psnr: 38.8433 - learning_rate: 3.1641e-05
# Epoch 40/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 159ms/step - loss: 0.0114 - psnr: 39.3147 - val_loss: 0.0112 - val_psnr: 38.7654 - learning_rate: 3.1641e-05
# Epoch 41/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 158ms/step - loss: 0.0119 - psnr: 38.8482 - val_loss: 0.0114 - val_psnr: 38.6912 - learning_rate: 3.1641e-05
# Epoch 42/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 156ms/step - loss: 0.0123 - psnr: 38.5285 - val_loss: 0.0117 - val_psnr: 38.5111 - learning_rate: 3.1641e-05
# Epoch 43/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 158ms/step - loss: 0.0118 - psnr: 39.1481 - val_loss: 0.0113 - val_psnr: 38.7144 - learning_rate: 3.1641e-05
# Epoch 44/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 158ms/step - loss: 0.0122 - psnr: 38.7504 - val_loss: 0.0113 - val_psnr: 38.7063 - learning_rate: 3.1641e-05
# Epoch 45/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 158ms/step - loss: 0.0115 - psnr: 39.3266 - val_loss: 0.0113 - val_psnr: 38.7460 - learning_rate: 2.3730e-05
# Epoch 46/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 158ms/step - loss: 0.0112 - psnr: 39.6048 - val_loss: 0.0114 - val_psnr: 38.5962 - learning_rate: 2.3730e-05
# Epoch 47/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 158ms/step - loss: 0.0113 - psnr: 39.4384 - val_loss: 0.0113 - val_psnr: 38.7121 - learning_rate: 2.3730e-05
# Epoch 48/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 159ms/step - loss: 0.0110 - psnr: 39.5400 - val_loss: 0.0115 - val_psnr: 38.5048 - learning_rate: 2.3730e-05
# Epoch 49/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 160ms/step - loss: 0.0113 - psnr: 39.4396 - val_loss: 0.0114 - val_psnr: 38.5400 - learning_rate: 2.3730e-05
# Epoch 50/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 157ms/step - loss: 0.0119 - psnr: 39.0441 - val_loss: 0.0112 - val_psnr: 38.6958 - learning_rate: 1.7798e-05
# Epoch 51/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 158ms/step - loss: 0.0110 - psnr: 39.6961 - val_loss: 0.0112 - val_psnr: 38.7197 - learning_rate: 1.7798e-05
# Epoch 52/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 160ms/step - loss: 0.0124 - psnr: 38.5274 - val_loss: 0.0115 - val_psnr: 38.5123 - learning_rate: 1.7798e-05
# Epoch 53/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 157ms/step - loss: 0.0117 - psnr: 39.2025 - val_loss: 0.0113 - val_psnr: 38.6131 - learning_rate: 1.7798e-05
# Epoch 54/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 168ms/step - loss: 0.0115 - psnr: 39.3344 - val_loss: 0.0111 - val_psnr: 38.7715 - learning_rate: 1.7798e-05
# Epoch 55/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 170ms/step - loss: 0.0114 - psnr: 39.3570 - val_loss: 0.0113 - val_psnr: 38.6518 - learning_rate: 1.3348e-05
# Epoch 56/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 171ms/step - loss: 0.0113 - psnr: 39.4865 - val_loss: 0.0114 - val_psnr: 38.6135 - learning_rate: 1.3348e-05
# Epoch 57/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 177ms/step - loss: 0.0116 - psnr: 39.2213 - val_loss: 0.0114 - val_psnr: 38.6466 - learning_rate: 1.3348e-05
# Epoch 58/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 177ms/step - loss: 0.0120 - psnr: 38.8598 - val_loss: 0.0112 - val_psnr: 38.7231 - learning_rate: 1.3348e-05
# Epoch 59/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 171ms/step - loss: 0.0112 - psnr: 39.3832 - val_loss: 0.0113 - val_psnr: 38.6998 - learning_rate: 1.3348e-05
# Epoch 60/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 181ms/step - loss: 0.0111 - psnr: 39.5614 - val_loss: 0.0112 - val_psnr: 38.7455 - learning_rate: 1.0011e-05
# Epoch 61/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 427ms/step - loss: 0.0112 - psnr: 39.5224 - val_loss: 0.0111 - val_psnr: 38.8229 - learning_rate: 1.0011e-05
# Epoch 62/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 160ms/step - loss: 0.0120 - psnr: 39.0851 - val_loss: 0.0111 - val_psnr: 38.7556 - learning_rate: 1.0011e-05
# Epoch 63/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 161ms/step - loss: 0.0110 - psnr: 39.6946 - val_loss: 0.0112 - val_psnr: 38.7300 - learning_rate: 1.0011e-05
# Epoch 64/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 159ms/step - loss: 0.0115 - psnr: 39.1849 - val_loss: 0.0111 - val_psnr: 38.7718 - learning_rate: 1.0011e-05
# Epoch 65/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 158ms/step - loss: 0.0110 - psnr: 39.5547 - val_loss: 0.0112 - val_psnr: 38.7311 - learning_rate: 7.5085e-06
# Epoch 66/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 160ms/step - loss: 0.0111 - psnr: 39.4753 - val_loss: 0.0112 - val_psnr: 38.7431 - learning_rate: 7.5085e-06
# Epoch 67/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 159ms/step - loss: 0.0115 - psnr: 39.3425 - val_loss: 0.0112 - val_psnr: 38.7036 - learning_rate: 7.5085e-06
# Epoch 68/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 159ms/step - loss: 0.0106 - psnr: 40.0126 - val_loss: 0.0111 - val_psnr: 38.7705 - learning_rate: 7.5085e-06
# Epoch 69/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 159ms/step - loss: 0.0107 - psnr: 39.9439 - val_loss: 0.0111 - val_psnr: 38.7902 - learning_rate: 7.5085e-06

# %% [markdown]
# ## Result and Visualization

# %% [markdown]
# ### Final Result on TestSet

# %%
# Final Result

print("Running predictions...")

# Pass the dual-stream inputs as a Python list
y_pred_all = fusion_model.predict([X1_test, X2_test], batch_size=batch_size)
y_pred_all = np.clip(y_pred_all, 0.0, 1.0) # Ensure strict 0-1 bounds

# Convert numpy arrays to tensors for the TF functions
y_true_tensor = tf.constant(y_test, dtype=tf.float32)
y_pred_tensor = tf.constant(y_pred_all, dtype=tf.float32)

# fusion_loss naturally returns a single mean value
final_loss = fusion_loss(y_true_tensor, y_pred_tensor).numpy()

# psnr and ssim return an array of scores (one for each image in the array). 
# use tf.reduce_mean to average them into a single final score.
final_psnr = tf.reduce_mean(psnr(y_true_tensor, y_pred_tensor)).numpy()
final_ssim = tf.reduce_mean(ssim(y_true_tensor, y_pred_tensor)).numpy()

final_mi = numpy_mutual_information(y_test, y_pred_all)

# Print Results
print("\n" + "="*40)
print("          FINAL TEST RESULTS")
print("="*40)
print(f"Test Loss (L1 + Edge) : {final_loss:.5f}")
print(f"Test PSNR             : {final_psnr:.4f} dB")
print(f"Test SSIM             : {final_ssim:.4f}")
print(f"Test Mutual Info (MI) : {final_mi:.4f}")
print("="*40)
# Out:
# Running predictions...
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step
#
# ========================================
#           FINAL TEST RESULTS
# ========================================
# Test Loss (L1 + Edge) : 0.01078
# Test PSNR             : 39.2606 dB
# Test SSIM             : 0.9916
# Test Mutual Info (MI) : 1.8114
# ========================================

# %% [markdown]
# ### Visualizion of Final Fused Image

# %%
import matplotlib.pyplot as plt
import numpy as np

# =====================================================================
# FUNCTION: SIDE-BY-SIDE FUSION VISUALIZATION (ENFORCED GRAYSCALE)
# =====================================================================
def show_fusion_results(x1_batch, x2_batch, fused_batch, num_images=4):
    """
    Plots the X1, X2, and Fused images side-by-side using clinical grayscale.
    """
    # Ensure we don't try to plot more images than exist in the batch
    num_images = min(num_images, x1_batch.shape[0])
    
    plt.figure(figsize=(15, 5 * num_images))
    for i in range(num_images):
        
        # Take the mean across channels to force a clean 2D slice for matplotlib
        x1_img = np.mean(x1_batch[i], axis=-1)
        x2_img = np.mean(x2_batch[i], axis=-1)
        fused_img = np.mean(fused_batch[i], axis=-1)
        
        # Plot X1 (Left) - Enforced grayscale
        plt.subplot(num_images, 3, i * 3 + 1)
        plt.imshow(x1_img, cmap='gray')
        plt.title(f"X1 (CT) - Sample {i+1}")
        plt.axis('off')
        
        # Plot X2 (Center) - Enforced grayscale
        plt.subplot(num_images, 3, i * 3 + 2)
        plt.imshow(x2_img, cmap='gray')
        plt.title(f"X2 (MRI) - Sample {i+1}")
        plt.axis('off')
        
        # Plot Fused (Right) - Enforced grayscale
        plt.subplot(num_images, 3, i * 3 + 3)
        plt.imshow(fused_img, cmap='gray')
        plt.title(f"Fused Output - Sample {i+1}")
        plt.axis('off')
        
    plt.tight_layout()
    plt.show()


# =====================================================================
# EXECUTION STEPS: INFERENCE AND DEPROCESSING
# =====================================================================

# 1. Grab a random batch of 4 indices
num_samples = X1_test.shape[0]
random_indices = np.random.choice(num_samples, size=4, replace=False)

# 2. Sample the separate test arrays
x1_sample = X1_test[random_indices].copy()
x2_sample = X2_test[random_indices].copy()

# 3. Run Inference via List passing
print("Running inference...")
predictions = fusion_model.predict([x1_sample, x2_sample])

# Clamp the predicted values safely between 0.0 and 1.0
predictions = np.clip(predictions, 0.0, 1.0)


# 4. Un-process the inputs for visualization
def deprocess_for_display(img_batch):
    """
    Dynamically normalizes preprocessed image batches back to a stable 
    [0.0, 1.0] range to prevent matplotlib from rendering black images.
    """
    img_cleaned = img_batch.copy()
    for i in range(img_cleaned.shape[0]):
        min_val = img_cleaned[i].min()
        max_val = img_cleaned[i].max()
        # Add a tiny epsilon value (1e-5) to prevent division by zero errors
        img_cleaned[i] = (img_cleaned[i] - min_val) / (max_val - min_val + 1e-5)
    return img_cleaned

# Apply the dynamic deprocessing formula
x1_visual = deprocess_for_display(x1_sample)
x2_visual = deprocess_for_display(x2_sample)


# 5. Plot the final results!
show_fusion_results(x1_visual, x2_visual, predictions, num_images=4)
# Out:
# Running inference...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step

# %%
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import FileLink, display

def plot_training_metrics_optimized(history_obj, title_name):
    """
    Generates publication-quality dual-axis plots with specific color grading.
    Both Warm-up and Fine-tuning stages are locked into a symmetric 8x8 grid matrix
    (8 X-axis intervals by 8 Y-axis intervals) with crisp integer labels for Epochs.
    """
    h = history_obj.history if hasattr(history_obj, 'history') else history_obj
    total_epochs = len(h['loss'])
    epochs = range(1, total_epochs + 1)
    
    plt.rcParams['font.family'] = 'sans-serif'
    plt.rcParams['axes.edgecolor'] = '#CCCCCC'
    plt.rcParams['axes.linewidth'] = 1.0
    
    fig, ax1 = plt.subplots(figsize=(8.5, 5.5), dpi=300)
    
    # ---------------- Left Y-Axis: PSNR Values (BLUE Theme) ----------------
    line1 = ax1.plot(epochs, h['psnr'], color='#1F77B4', linestyle='-', linewidth=2.2, label='Train PSNR', zorder=3)
    line2 = ax1.plot(epochs, h['val_psnr'], color='#4A90E2', linestyle='-.', linewidth=2.2, label='Validation PSNR', zorder=3)
    
    ax1.set_xlabel('Epochs', fontsize=12, labelpad=10)
    ax1.set_ylabel('PSNR (dB)', fontsize=12, labelpad=10, color='#1F77B4', fontweight='bold')
    
    # Force X-axis limits securely based on epoch length
    ax1.set_xlim(1, total_epochs)
    
    # AUTO-GRID: Force exactly 8 intervals, safely mapped to clean integers
    x_ticks = np.linspace(1, total_epochs, 9).astype(int)
    x_ticks = np.unique(x_ticks)  # Prevents duplicate ticks if total_epochs < 8
    ax1.set_xticks(x_ticks)
    
    # ---------------- Left Axis (PSNR) Bounds & Ticks ----------------
    if "Fine" in title_name:
        # Fine-tuning: Range 10 to 42 split into 8 intervals (steps of 4)
        ax1.set_ylim(10, 42)
        ax1.set_yticks(np.linspace(10, 42, 9))
    else:
        # Warm-up: Range 0 to 40 split into 8 intervals (steps of 5)
        ax1.set_ylim(0, 40)
        ax1.set_yticks(np.linspace(0, 40, 9))
        
    ax1.tick_params(axis='y', labelsize=10.5, labelcolor='#1F77B4')
    ax1.tick_params(axis='x', labelsize=10.5)
    
    # OPTIMIZED GRID: Forms a crisp symmetric matrix background
    ax1.grid(True, linestyle=':', alpha=0.75, color='#B0B0B0', linewidth=0.8, zorder=1)
    
    # ---------------- Right Y-Axis: Loss Values (RED Theme) ----------------
    ax2 = ax1.twinx()
    line3 = ax2.plot(epochs, h['loss'], color='#D62728', linestyle='--', linewidth=2.0, label='Train Loss', zorder=3)
    line4 = ax2.plot(epochs, h['val_loss'], color='#FF6B6B', linestyle=':', linewidth=2.0, label='Validation Loss', zorder=3)
    
    ax2.set_ylabel('Loss', fontsize=12, labelpad=10, color='#D62728', fontweight='bold')
    
    # ---------------- Right Axis (Loss) Bounds & Ticks ----------------
    if "Fine" in title_name:
        # Fine-tuning: Range 0.009 to 0.073 split into 8 intervals (steps of 0.008)
        ax2.set_ylim(0.009, 0.073)
        ax2.set_yticks(np.linspace(0.009, 0.073, 9))
    else:
        # Warm-up: Range 0.0 to 0.40 split into 8 intervals (steps of 0.05)
        ax2.set_ylim(0.0, 0.40)
        ax2.set_yticks(np.linspace(0.0, 0.40, 9))
        
    ax2.tick_params(axis='y', labelsize=10.5, labelcolor='#D62728')
    
    # ---------------- Legend Layout (Inside Frame) ----------------
    all_lines = line1 + line2 + line3 + line4
    all_labels = [l.get_label() for l in all_lines]
    
    leg = ax1.legend(
        all_lines, 
        all_labels, 
        loc='center right', 
        frameon=True, 
        facecolor='white', 
        edgecolor='#E0E0E0', 
        fontsize=10
    )
    
    if leg:
        leg.set_zorder(4)
    
    plt.title(title_name, fontsize=14, fontweight='bold', pad=15)
    plt.tight_layout()
    
    save_filename = title_name.lower().replace(' ', '_') + '_curve.png'
    plt.savefig(save_filename, dpi=300, bbox_inches='tight')
    plt.show()
    return save_filename

# --- Execution Block ---
fn_warmup = plot_training_metrics_optimized(history_warmup, 'Warm-up Training Stage')
display(FileLink(fn_warmup))

fn_finetune = plot_training_metrics_optimized(history_finetune, 'Fine-tuning Training Stage')
display(FileLink(fn_finetune))
# Out:
# /kaggle/working/warm-up_training_stage_curve.png
# /kaggle/working/fine-tuning_training_stage_curve.png

# %%
# --- Rename and Save the Final Trained Model ---

# Update the model's internal name attribute for DenseNet121 CT-MRI
fusion_model.name = "DenseNet121_CT_MRI"

# Construct the dynamic file path using the updated name and the final Test PSNR score
model_save_path = f"/kaggle/working/{fusion_model.name}_(PSNR_{final_psnr:.2f}dB).keras"

print(f"Saving model to: {model_save_path}")
fusion_model.save(model_save_path)
print("Model saved successfully!")
# Out:
# Saving model to: /kaggle/working/DenseNet121_CT_MRI_(PSNR_39.26dB).keras
# Model saved successfully!
