# %% [markdown]
# # Medical Image Fusion
# A project to fuse a pair of medical images (CT-MRI, PET-MRI, SPECT-MRI) into a single image for better interpretation.
#
# ### Model Definition
# Using a 4-stage model to extract features, learn, and reconstruct images.
#
# ### Model Structure
# * Muili-Stream Encoder: Used two separate pre-trained CNNs for extracting feature maps at various resolutions.
# * Feature Fusion: Combines the feature maps extracted by encoders.
# * Custom UNet Decoder: Upscales and reconstructs the image by using the feature maps.
# * Image Refiner (Optional): Refines the final image based of redundant feature maps.

# %% [markdown]
# ## Environment Initalization

# %%
import os
import cv2
import gc
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

import tensorflow as tf

# GPU Setup & Memory Growth
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print(f"TensorFlow is using GPU: {gpus[0].name}")
    except RuntimeError as e:
        print(e)
else:
    print("TensorFlow is using CPU")
# Out:
# TensorFlow is using GPU: /physical_device:GPU:0

# %% [markdown]
# ## Dataset Preprocessing

# %%
# CT-MRI
dir_1 = '/kaggle/input/datasets/mdrafsanyeasir/thesis45-medical-image/Havard-Medical-Image-Fusion-Datasets-main/CT-MRI/CT'
dir_2 = '/kaggle/input/datasets/mdrafsanyeasir/thesis45-medical-image/Havard-Medical-Image-Fusion-Datasets-main/CT-MRI/MRI'


# PET-MRI
# dir_1 = '/kaggle/input/datasets/mdrafsanyeasir/thesis45-medical-image/Havard-Medical-Image-Fusion-Datasets-main/PET-MRI/MRI'
# dir_2 = '/kaggle/input/datasets/mdrafsanyeasir/thesis45-medical-image/Havard-Medical-Image-Fusion-Datasets-main/PET-MRI/PET'


# SPECT-MRI
# dir_1 = '/kaggle/input/datasets/mdrafsanyeasir/thesis45-medical-image/Havard-Medical-Image-Fusion-Datasets-main/SPECT-MRI/MRI'
# dir_2 = '/kaggle/input/datasets/mdrafsanyeasir/thesis45-medical-image/Havard-Medical-Image-Fusion-Datasets-main/SPECT-MRI/SPECT'

# %% [markdown]
# ### Muti-Stream Data Loading

# %%
from tensorflow.keras.preprocessing.image import load_img, img_to_array

def load_and_process_fusion_data_v1(dir_1, dir_2, target_size=(256, 256)):
    """
    Dual-Stream loader for Double Grayscale medical image fusion.
    Returns X1 (3-Ch), X2 (3-Ch), and y (Fused Target 3-Ch).
    """
    filenames = sorted(os.listdir(dir_1))
    num_samples = len(filenames)
    
    # 1. PRE-ALLOCATE MEMORY
    # All arrays must be 3-channel to satisfy the pre-trained ImageNet encoders
    X1 = np.empty((num_samples, target_size[0], target_size[1], 3), dtype=np.float32) 
    X2 = np.empty((num_samples, target_size[0], target_size[1], 3), dtype=np.float32) 
    y  = np.empty((num_samples, target_size[0], target_size[1], 3), dtype=np.float32) 
    
    for i, fname in enumerate(tqdm(filenames, desc="Processing Images (gray-gray) ...")):
        path_dir_1 = os.path.join(dir_1, fname)
        path_dir_2 = os.path.join(dir_2, fname)
        
        # Load images directly into numpy arrays [0, 255]
        x1_arr = img_to_array(load_img(path_dir_1, color_mode="grayscale", target_size=target_size))
        x2_arr = img_to_array(load_img(path_dir_2, color_mode="grayscale", target_size=target_size))
        
        # --- INPUT 1: Grayscale Image ---
        # Repeat the 1-channel into 3 identical channels for pretrained CNNs
        X1[i] = np.repeat(x1_arr, 3, axis=-1) 
        
        # --- INPUT 2: Grayscale Image ---
        X2[i] = np.repeat(x2_arr, 3, axis=-1)
        
        # --- TARGET CREATION ---
        
        # FUSION
        
        ## OPTION A: The Maximum Rule (Default)
        # Ensures that the brightest structural edge from either scan survives
        fused = np.maximum(x1_arr, x2_arr)
        
        ## OPTION B: The Averaging Rule (Uncomment to test)
        # Blends the structural intensities evenly
        # fused = (x1_arr + x2_arr) / 2.0
        
        # Stacking for 3-ch image
        y[i] = np.repeat(fused, 3, axis=-1)

    gc.collect()
    
    return X1, X2, y



def load_and_process_fusion_data_v2(gray_img_dir, color_img_dir, target_size=(256, 256)):
    """
    Dual-Stream loader for Grayscale and RGB medical image fusion.
    Returns X1 (3-Ch), X2 (3-Ch), and y (Fused Target 3-Ch).
    """
    filenames = sorted(os.listdir(gray_img_dir))
    num_samples = len(filenames)
    
    # 1. PRE-ALLOCATE MEMORY
    # All arrays must be 3-channel to satisfy the pre-trained ImageNet encoders
    X1 = np.empty((num_samples, target_size[0], target_size[1], 3), dtype=np.float32) 
    X2 = np.empty((num_samples, target_size[0], target_size[1], 3), dtype=np.float32) 
    y  = np.empty((num_samples, target_size[0], target_size[1], 3), dtype=np.float32) 
    
    for i, fname in enumerate(tqdm(filenames, desc="Processing Images (gray-rgb) ...")):
        path_gray = os.path.join(gray_img_dir, fname)
        path_color = os.path.join(color_img_dir, fname)
        
        # Load images directly into numpy arrays [0, 255]
        x1_arr = img_to_array(load_img(path_gray, color_mode="grayscale", target_size=target_size))
        x2_arr = img_to_array(load_img(path_color, color_mode="rgb", target_size=target_size))
        
        # --- INPUT 1: Grayscale Image ---
        # Repeat the 1-channel into 3 identical channels for pretrained CNNs
        X1[i] = np.repeat(x1_arr, 3, axis=-1) 
        
        # --- INPUT 2: Color Image ---
        X2[i] = x2_arr 
        
        # --- TARGET CREATION (The OpenCV Math) ---
        # OpenCV's float32 color conversions require values to be strictly between 0.0 and 1.0
        x1_norm = x1_arr / 255.0
        x2_norm = x2_arr / 255.0
        
        # 1. Convert RGB to YCrCb using cv2
        # (Note: Keras load_img returns RGB, so we explicitly use COLOR_RGB2YCrCb)
        x2_ycrcb = cv2.cvtColor(x2_norm, cv2.COLOR_RGB2YCrCb)
        
        # 2. Extract Y (Structure), Cr and Cb (Color)
        # Using [:, :, 0:1] keeps the trailing dimension (256, 256, 1) instead of flat (256, 256)
        Y_x2  = x2_ycrcb[:, :, 0:1]
        Cr_x2 = x2_ycrcb[:, :, 1:2]
        Cb_x2 = x2_ycrcb[:, :, 2:3]
        
        # The grayscale natively serves as our structural Y channel
        Y_x1= x1_norm
        
        # 3. FUSION
        
        # OPTION A: The Maximum Rule (Default)
        # Ensures that the brightest structural edge from either scan survives
        Y_fused = np.maximum(Y_x1, Y_x2)
        
        # OPTION B: The Averaging Rule (Uncomment to test)
        # Blends the structural intensities evenly
        # Y_fused = (Y_x1 + Y_x2) / 2.0
        
        # 4. Stack the fused structure back together with the metabolic color
        target_ycrcb = np.concatenate([Y_fused, Cr_x2, Cb_x2], axis=-1)
        
        # 5. Convert back to RGB using cv2 and scale back to 255
        target_rgb = cv2.cvtColor(target_ycrcb, cv2.COLOR_YCrCb2RGB)
        
        # Clip guarantees floating point math doesn't accidentally yield 255.0001 (which crashes matplotlib later)
        y[i] = np.clip(target_rgb * 255.0, 0.0, 255.0)

    gc.collect()
    
    return X1, X2, y

def load_and_process_fusion_data_v3(dir_1, dir_2, target_size=(256, 256)):
    """
    Universal Dual-Stream loader for ANY combination of Grayscale and RGB images.
    Returns X1 (3-Ch), X2 (3-Ch), and y (Fused Target 3-Ch).
    """
    filenames = sorted(os.listdir(dir_1))
    num_samples = len(filenames)
    
    X1 = np.empty((num_samples, target_size[0], target_size[1], 3), dtype=np.float32) 
    X2 = np.empty((num_samples, target_size[0], target_size[1], 3), dtype=np.float32) 
    y  = np.empty((num_samples, target_size[0], target_size[1], 3), dtype=np.float32) 
    
    for i, fname in enumerate(tqdm(filenames, desc="Processing Images (universal) ...")):
        path_1 = os.path.join(dir_1, fname)
        path_2 = os.path.join(dir_2, fname)
        
        # 1. Load BOTH as RGB (Keras will duplicate channels for grayscale images automatically)
        x1_arr = img_to_array(load_img(path_1, color_mode="rgb", target_size=target_size))
        x2_arr = img_to_array(load_img(path_2, color_mode="rgb", target_size=target_size))
        
        # Save exact inputs to RAM
        X1[i] = x1_arr 
        X2[i] = x2_arr 
        
        # 2. Normalize to [0.0, 1.0] for OpenCV
        x1_norm = x1_arr / 255.0
        x2_norm = x2_arr / 255.0
        
        # 3. Convert both to YCrCb
        ycrcb_1 = cv2.cvtColor(x1_norm, cv2.COLOR_RGB2YCrCb)
        ycrcb_2 = cv2.cvtColor(x2_norm, cv2.COLOR_RGB2YCrCb)
        
        # Extract channels
        Y1, Cr1, Cb1 = ycrcb_1[:, :, 0:1], ycrcb_1[:, :, 1:2], ycrcb_1[:, :, 2:3]
        Y2, Cr2, Cb2 = ycrcb_2[:, :, 0:1], ycrcb_2[:, :, 1:2], ycrcb_2[:, :, 2:3]
        
        # 4. STRUCTURAL FUSION (The Maximum Rule for Luminance)
        Y_fused = np.maximum(Y1, Y2)
        
        # 5. CHROMINANCE FUSION (The Saturation Mask)
        # Calculate how far each pixel is from absolute gray (0.5)
        # The sum of absolute differences gives us a "Color Intensity" score
        saturation_1 = np.abs(Cr1 - 0.5) + np.abs(Cb1 - 0.5)
        saturation_2 = np.abs(Cr2 - 0.5) + np.abs(Cb2 - 0.5)
        
        # Create a boolean mask: True if Image 2 has more color, False if Image 1 has more color
        mask = saturation_2 > saturation_1
        
        # Use np.where to dynamically route the original, unaltered color channels
        Cr_fused = np.where(mask, Cr2, Cr1)
        Cb_fused = np.where(mask, Cb2, Cb1)
        
        # 6. Stack and convert back to RGB
        target_ycrcb = np.concatenate([Y_fused, Cr_fused, Cb_fused], axis=-1)
        target_rgb = cv2.cvtColor(target_ycrcb, cv2.COLOR_YCrCb2RGB)
        
        y[i] = np.clip(target_rgb * 255.0, 0.0, 255.0)

    gc.collect()
    
    return X1, X2, y

# %% [markdown]
# ### Splitting into Train, Test and Validation sets

# %%
from sklearn.model_selection import train_test_split

# X1, X2, y = load_and_process_fusion_data_v1(dir_1, dir_2)    # For CT-MRI only
# X1, X2, y = load_and_process_fusion_data_v2(dir_1, dir_2)    # For PET-MRI, SPECT-MRI only

X1, X2, y = load_and_process_fusion_data_v3(dir_1, dir_2)    # Universal

# 1. Split the data using a strict random state to keep them aligned
X1_train, X1_temp, X2_train, X2_temp, y_train, y_temp = train_test_split(
    X1, X2, y, test_size=0.30, random_state=42
)

# 2. Split the temp arrays into Validation and Test
X1_test, X1_val, X2_test, X2_val, y_test, y_val = train_test_split(
    X1_temp, X2_temp, y_temp, test_size=(1/3), random_state=42
)

print(f"X1_train shape: {X1_train.shape} (70%)")
print(f"X1_test shape:  {X1_test.shape} (20%)")
print(f"X1_val shape:   {X1_val.shape} (10%)")
print()

print(f"X2_train shape: {X2_train.shape} (70%)")
print(f"X2_test shape:  {X2_test.shape} (20%)")
print(f"X2_val shape:   {X2_val.shape} (10%)")
print()

print(f"y_train shape: {y_train.shape} (70%)")
print(f"y_test shape:  {y_test.shape} (20%)")
print(f"y_val shape:   {y_val.shape} (10%)")
# Out:
# Processing Images (universal) ...: 100%|██████████| 184/184 [00:03<00:00, 49.05it/s]
# X1_train shape: (128, 256, 256, 3) (70%)
# X1_test shape:  (37, 256, 256, 3) (20%)
# X1_val shape:   (19, 256, 256, 3) (10%)
#
# X2_train shape: (128, 256, 256, 3) (70%)
# X2_test shape:  (37, 256, 256, 3) (20%)
# X2_val shape:   (19, 256, 256, 3) (10%)
#
# y_train shape: (128, 256, 256, 3) (70%)
# y_test shape:  (37, 256, 256, 3) (20%)
# y_val shape:   (19, 256, 256, 3) (10%)

# %% [markdown]
# ### (Optional) Datasets Verification

# %%
import random

def plot_fusion_triplet(x1_array, x2_array, target_array, num_samples=2):
    """
    Plots a row of [X1, X2, Fused Target] to verify alignment and color logic.
    """
    # Pick random indices to check
    # random.seed(213)
    indices = random.sample(range(len(x1_array)), num_samples)
    
    plt.figure(figsize=(15, 5 * num_samples))
    
    for row, idx in enumerate(indices):
        # Scale down to [0.0, 1.0] solely for matplotlib's float32 rendering requirements
        img_mri = x1_array[idx] / 255.0
        img_pet = x2_array[idx] / 255.0
        img_fused = target_array[idx] / 255.0
        
        # Plot X1
        plt.subplot(num_samples, 3, row * 3 + 1)
        plt.imshow(img_mri)
        plt.title(f"X1 - Idx {idx}")
        plt.axis('off')
        
        # Plot X2
        plt.subplot(num_samples, 3, row * 3 + 2)
        plt.imshow(img_pet)
        plt.title(f"X2 - Idx {idx}")
        plt.axis('off')
        
        # Plot y (Fused Target)
        plt.subplot(num_samples, 3, row * 3 + 3)
        plt.imshow(img_fused)
        plt.title(f"y: Fused Ground Truth - Idx {idx}")
        plt.axis('off')
        
    plt.tight_layout()
    plt.show()

# Run the plotter to check your training data!
plot_fusion_triplet(X1_test, X2_test, y_test, num_samples=1)
plot_fusion_triplet(X1_train, X2_train, y_train, num_samples=1)
plot_fusion_triplet(X1_val, X2_val, y_val, num_samples=1)

# %% [markdown]
# ### Image Normalization

# %%
from tensorflow.keras.applications.efficientnet import preprocess_input

# Normalize Input Images
X1_train = preprocess_input(X1_train)
X1_test = preprocess_input(X1_test)
X1_val = preprocess_input(X1_val)

X2_train = preprocess_input(X2_train)
X2_test = preprocess_input(X2_test)
X2_val = preprocess_input(X2_val)

y_train = y_train.astype("float32") / 255.0
y_test = y_test.astype("float32") / 255.0
y_val = y_val.astype("float32") / 255.0

# %% [markdown]
# ### Dynamic Runtime Augmentation

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# 1. Define the augmentation parameters
aug_args = dict(
    rotation_range=15,       # Rotate up to 10 degrees
    width_shift_range=0.1,  # Shift left/right by 5%
    height_shift_range=0.05, # Shift up/down by 5%
    zoom_range=0.05,         # Zoom in/out by 5%
    horizontal_flip=True,    # Left/Right flip is usually safe for most axial medical scans
    fill_mode='nearest'      # How to fill missing pixels after shifting
)

# 2. Instantiate generator
datagen = ImageDataGenerator(**aug_args)

seed_value = 42 # Must for synchronizing the generators
batch_size = 4 

# 3. Flow from the RAM arrays
x1_gen = datagen.flow(X1_train, batch_size=batch_size, seed=seed_value, shuffle=True)
x2_gen = datagen.flow(X2_train, batch_size=batch_size, seed=seed_value, shuffle=True)
target_gen = datagen.flow(y_train, batch_size=batch_size, seed=seed_value, shuffle=True)

# 3. Zip them into a Dual-Stream Generator
def dual_stream_train_generator(x1_gen, x2_gen, t_gen):
    while True:
        # Must use a Dictionary matching Input(name="...") layers 
        inputs_dict = {
            "input_x1": next(x1_gen),
            "input_x2": next(x2_gen)
        }
        
        yield (inputs_dict, next(t_gen))

train_fusion_gen = dual_stream_train_generator(x1_gen, x2_gen, target_gen)

# (Optional) Test the generator to make sure the shapes are correct
sample_inputs, sample_targets = next(train_fusion_gen)

print(f"Input 1 shape: {sample_inputs['input_x1'].shape}") # Should be (batch_size, x, x, 3)
print(f"Input 2 shape: {sample_inputs['input_x2'].shape}") # Should be (batch_size, x, x, 3)
print(f"Target batch shape:  {sample_targets.shape}")   # Should be (batch_size, x, x, 3)
# Out:
# Input 1 shape: (4, 256, 256, 3)
# Input 2 shape: (4, 256, 256, 3)
# Target batch shape:  (4, 256, 256, 3)

# %% [markdown]
# ## Model Creation

# %% [markdown]
# ### Model Structure

# %%
from tensorflow.keras import applications as app
from tensorflow.keras import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Conv2DTranspose, Activation, BatchNormalization, Concatenate



# --- Stage 1: MULTI-STREAM ENCODER ---

# Left Stream encoder
input_x1 = Input(shape=X1_val.shape[1:], name="input_x1")
left_encoder = app.EfficientNetB0(weights='imagenet', include_top=False, input_tensor=input_x1)

# Setting unique names for each layers (needed when using same models or familly)
for layer in left_encoder.layers[1:]:
    layer.name = layer.name + "_left"

left_fmap = left_encoder.output

# Right Stream encoder
input_x2 = Input(shape=X2_val.shape[1:], name="input_x2")
right_encoder = app.EfficientNetB0(weights='imagenet', include_top=False, input_tensor=input_x2)

# Setting unique names for each layers (needed when using same models or familly)
for layer in right_encoder.layers[1:]:
    layer.name = layer.name + "_right"

right_fmap = right_encoder.output



# --- Stage 2: FEATURE FUSION ---

if int(left_fmap.shape[-2]) != int(right_fmap.shape[-2]):
    raise ValueError(f"Uncompatible Encoders: The Encoders are not compatible with each other")
    
combined_fmap = Concatenate(axis=-1, name="feature_map_combine")([left_fmap, right_fmap])

# Params for Decoder
fmap = min(2048, int(left_fmap.shape[-1]) + int(right_fmap.shape[-1])) 
res = int(combined_fmap.shape[-2])
target_res = int(y_val.shape[1])

# Feature Refiner
x = Conv2D(fmap, kernel_size=(3, 3), padding='same', name="feature_map_refiner")(combined_fmap)
x = BatchNormalization()(x)
x = Activation('relu')(x)



# --- Stage 3: DYNAMIC CUSTOM U-NET DECODER ---

# Image reconstruction
while res < target_res:
    res *= 2
    fmap = max(16, int(fmap / 2))

    # Deconvolution and Upscalling
    x = Conv2DTranspose(fmap, kernel_size=(3, 3), padding='same', strides=2, name=f"decoder_{res}")(x)
    
    # Dynamic Search for the Skip Connection on Left Stream
    target_layer_name_left = None
    
    # Traverse backwards to find the deepest layer at the target resolution
    for layer in left_encoder.layers[::-1]:
        shape = layer.output.shape
        if len(shape) == 4 and shape[1] == res and shape[2] == res:
            target_layer_name_left = layer.name
            break
            
    if target_layer_name_left is None:
        raise ValueError(f"Unsupported Encoder: Could not find a valid 4D skip connection layer for resolution {res}x{res} inside the left stream encoder.")

    left_skip_tensor = left_encoder.get_layer(target_layer_name_left).output

    # Dynamic Search for the Skip Connection on Right Stream
    target_layer_name_right = None
    
    # Traverse backwards to find the deepest layer at the target resolution
    for layer in right_encoder.layers[::-1]:
        shape = layer.output.shape
        if len(shape) == 4 and shape[1] == res and shape[2] == res:
            target_layer_name_right = layer.name
            break
            
    if target_layer_name_right is None:
        raise ValueError(f"Unsupported Encoder: Could not find a valid 4D skip connection layer for resolution {res}x{res} inside the right stream encoder.")

    right_skip_tensor = right_encoder.get_layer(target_layer_name_right).output
    
    print(f"Linking Skip Connection at {res}x{res}: decoder_{res} + {target_layer_name_left} + {target_layer_name_right}")
    
    # Combining Skip Connection with upscaled map
    x = Concatenate(axis=-1, name=f"skip_concat_{res}")([x, left_skip_tensor, right_skip_tensor])
    
    # Upscaled map refiner
    x = Conv2D(fmap, kernel_size=(3, 3), padding='same', name=f"decoder_refine_{res}")(x) 
    x = BatchNormalization()(x)
    x = Activation('relu')(x)


# --- Stage 4: (Optional) FINAL IMAGE REFINER ---
while fmap > 16:
    fmap = int(fmap / 2)
    x = Conv2D(fmap, kernel_size=(3, 3), padding='same', name=f"opt_refiner_{fmap}")(x) 
    x = BatchNormalization()(x)
    x = Activation('relu')(x)


# Final Output Layer: 1x1 Conv to collapse to 1 channel, Sigmoid for 0.0 to 1.0 mapping
fused_output = Conv2D(3, kernel_size=(1, 1), activation='sigmoid', name="fused_output")(x)

# Build and Instantiate the Model
fusion_model = Model(inputs=[input_x1, input_x2], outputs=fused_output, name="FusionNet")
fusion_model.summary()
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1783092778.859808      22 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Linking Skip Connection at 16x16: decoder_16 + block6a_expand_activation_left + block6a_expand_activation_right
# Linking Skip Connection at 32x32: decoder_32 + block4a_expand_activation_left + block4a_expand_activation_right
# Linking Skip Connection at 64x64: decoder_64 + block3a_expand_activation_left + block3a_expand_activation_right
# Linking Skip Connection at 128x128: decoder_128 + block2a_expand_activation_left + block2a_expand_activation_right
# Linking Skip Connection at 256x256: decoder_256 + rescaling_1_left + rescaling_3_right
# Model: "FusionNet"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_x1            │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_x2            │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling_left      │ (None, 256, 256,  │          0 │ input_x1[0][0]    │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling_2_right   │ (None, 256, 256,  │          0 │ input_x2[0][0]    │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normalization_left  │ (None, 256, 256,  │          7 │ rescaling_left[0… │
# │ (Normalization)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normalization_1_ri… │ (None, 256, 256,  │          7 │ rescaling_2_righ… │
# │ (Normalization)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling_1_left    │ (None, 256, 256,  │          0 │ normalization_le… │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling_3_right   │ (None, 256, 256,  │          0 │ normalization_1_… │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_conv_pad_left  │ (None, 257, 257,  │          0 │ rescaling_1_left… │
# │ (ZeroPadding2D)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_conv_pad_right │ (None, 257, 257,  │          0 │ rescaling_3_righ… │
# │ (ZeroPadding2D)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_conv_left      │ (None, 128, 128,  │        864 │ stem_conv_pad_le… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_conv_right     │ (None, 128, 128,  │        864 │ stem_conv_pad_ri… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_bn_left        │ (None, 128, 128,  │        128 │ stem_conv_left[0… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_bn_right       │ (None, 128, 128,  │        128 │ stem_conv_right[… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_activation_le… │ (None, 128, 128,  │          0 │ stem_bn_left[0][… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_activation_ri… │ (None, 128, 128,  │          0 │ stem_bn_right[0]… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_dwconv_left │ (None, 128, 128,  │        288 │ stem_activation_… │
# │ (DepthwiseConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_dwconv_rig… │ (None, 128, 128,  │        288 │ stem_activation_… │
# │ (DepthwiseConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_bn_left     │ (None, 128, 128,  │        128 │ block1a_dwconv_l… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_bn_right    │ (None, 128, 128,  │        128 │ block1a_dwconv_r… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_activation… │ (None, 128, 128,  │          0 │ block1a_bn_left[… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_activation… │ (None, 128, 128,  │          0 │ block1a_bn_right… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_squeeze… │ (None, 32)        │          0 │ block1a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_squeeze… │ (None, 32)        │          0 │ block1a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_reshape… │ (None, 1, 1, 32)  │          0 │ block1a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_reshape… │ (None, 1, 1, 32)  │          0 │ block1a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_reduce_… │ (None, 1, 1, 8)   │        264 │ block1a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_reduce_… │ (None, 1, 1, 8)   │        264 │ block1a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_expand_… │ (None, 1, 1, 32)  │        288 │ block1a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_expand_… │ (None, 1, 1, 32)  │        288 │ block1a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_excite_… │ (None, 128, 128,  │          0 │ block1a_activati… │
# │ (Multiply)          │ 32)               │            │ block1a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_excite_… │ (None, 128, 128,  │          0 │ block1a_activati… │
# │ (Multiply)          │ 32)               │            │ block1a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_project_co… │ (None, 128, 128,  │        512 │ block1a_se_excit… │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_project_co… │ (None, 128, 128,  │        512 │ block1a_se_excit… │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_project_bn… │ (None, 128, 128,  │         64 │ block1a_project_… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_project_bn… │ (None, 128, 128,  │         64 │ block1a_project_… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_expand_con… │ (None, 128, 128,  │      1,536 │ block1a_project_… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_expand_con… │ (None, 128, 128,  │      1,536 │ block1a_project_… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_expand_bn_… │ (None, 128, 128,  │        384 │ block2a_expand_c… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_expand_bn_… │ (None, 128, 128,  │        384 │ block2a_expand_c… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_expand_act… │ (None, 128, 128,  │          0 │ block2a_expand_b… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_expand_act… │ (None, 128, 128,  │          0 │ block2a_expand_b… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_dwconv_pad… │ (None, 129, 129,  │          0 │ block2a_expand_a… │
# │ (ZeroPadding2D)     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_dwconv_pad… │ (None, 129, 129,  │          0 │ block2a_expand_a… │
# │ (ZeroPadding2D)     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_dwconv_left │ (None, 64, 64,    │        864 │ block2a_dwconv_p… │
# │ (DepthwiseConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_dwconv_rig… │ (None, 64, 64,    │        864 │ block2a_dwconv_p… │
# │ (DepthwiseConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_bn_left     │ (None, 64, 64,    │        384 │ block2a_dwconv_l… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_bn_right    │ (None, 64, 64,    │        384 │ block2a_dwconv_r… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_activation… │ (None, 64, 64,    │          0 │ block2a_bn_left[… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_activation… │ (None, 64, 64,    │          0 │ block2a_bn_right… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_squeeze… │ (None, 96)        │          0 │ block2a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_squeeze… │ (None, 96)        │          0 │ block2a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_reshape… │ (None, 1, 1, 96)  │          0 │ block2a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_reshape… │ (None, 1, 1, 96)  │          0 │ block2a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_reduce_… │ (None, 1, 1, 4)   │        388 │ block2a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_reduce_… │ (None, 1, 1, 4)   │        388 │ block2a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_expand_… │ (None, 1, 1, 96)  │        480 │ block2a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_expand_… │ (None, 1, 1, 96)  │        480 │ block2a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_excite_… │ (None, 64, 64,    │          0 │ block2a_activati… │
# │ (Multiply)          │ 96)               │            │ block2a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_excite_… │ (None, 64, 64,    │          0 │ block2a_activati… │
# │ (Multiply)          │ 96)               │            │ block2a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_project_co… │ (None, 64, 64,    │      2,304 │ block2a_se_excit… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_project_co… │ (None, 64, 64,    │      2,304 │ block2a_se_excit… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_project_bn… │ (None, 64, 64,    │         96 │ block2a_project_… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_project_bn… │ (None, 64, 64,    │         96 │ block2a_project_… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_expand_con… │ (None, 64, 64,    │      3,456 │ block2a_project_… │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_expand_con… │ (None, 64, 64,    │      3,456 │ block2a_project_… │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_expand_bn_… │ (None, 64, 64,    │        576 │ block2b_expand_c… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_expand_bn_… │ (None, 64, 64,    │        576 │ block2b_expand_c… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_expand_act… │ (None, 64, 64,    │          0 │ block2b_expand_b… │
# │ (Activation)        │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_expand_act… │ (None, 64, 64,    │          0 │ block2b_expand_b… │
# │ (Activation)        │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_dwconv_left │ (None, 64, 64,    │      1,296 │ block2b_expand_a… │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_dwconv_rig… │ (None, 64, 64,    │      1,296 │ block2b_expand_a… │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_bn_left     │ (None, 64, 64,    │        576 │ block2b_dwconv_l… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_bn_right    │ (None, 64, 64,    │        576 │ block2b_dwconv_r… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_activation… │ (None, 64, 64,    │          0 │ block2b_bn_left[… │
# │ (Activation)        │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_activation… │ (None, 64, 64,    │          0 │ block2b_bn_right… │
# │ (Activation)        │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_squeeze… │ (None, 144)       │          0 │ block2b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_squeeze… │ (None, 144)       │          0 │ block2b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_reshape… │ (None, 1, 1, 144) │          0 │ block2b_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_reshape… │ (None, 1, 1, 144) │          0 │ block2b_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_reduce_… │ (None, 1, 1, 6)   │        870 │ block2b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_reduce_… │ (None, 1, 1, 6)   │        870 │ block2b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_expand_… │ (None, 1, 1, 144) │      1,008 │ block2b_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_expand_… │ (None, 1, 1, 144) │      1,008 │ block2b_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_excite_… │ (None, 64, 64,    │          0 │ block2b_activati… │
# │ (Multiply)          │ 144)              │            │ block2b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_excite_… │ (None, 64, 64,    │          0 │ block2b_activati… │
# │ (Multiply)          │ 144)              │            │ block2b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_project_co… │ (None, 64, 64,    │      3,456 │ block2b_se_excit… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_project_co… │ (None, 64, 64,    │      3,456 │ block2b_se_excit… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_project_bn… │ (None, 64, 64,    │         96 │ block2b_project_… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_project_bn… │ (None, 64, 64,    │         96 │ block2b_project_… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_drop_left   │ (None, 64, 64,    │          0 │ block2b_project_… │
# │ (Dropout)           │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_drop_right  │ (None, 64, 64,    │          0 │ block2b_project_… │
# │ (Dropout)           │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_add_left    │ (None, 64, 64,    │          0 │ block2b_drop_lef… │
# │ (Add)               │ 24)               │            │ block2a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_add_right   │ (None, 64, 64,    │          0 │ block2b_drop_rig… │
# │ (Add)               │ 24)               │            │ block2a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_expand_con… │ (None, 64, 64,    │      3,456 │ block2b_add_left… │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_expand_con… │ (None, 64, 64,    │      3,456 │ block2b_add_righ… │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_expand_bn_… │ (None, 64, 64,    │        576 │ block3a_expand_c… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_expand_bn_… │ (None, 64, 64,    │        576 │ block3a_expand_c… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_expand_act… │ (None, 64, 64,    │          0 │ block3a_expand_b… │
# │ (Activation)        │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_expand_act… │ (None, 64, 64,    │          0 │ block3a_expand_b… │
# │ (Activation)        │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_dwconv_pad… │ (None, 67, 67,    │          0 │ block3a_expand_a… │
# │ (ZeroPadding2D)     │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_dwconv_pad… │ (None, 67, 67,    │          0 │ block3a_expand_a… │
# │ (ZeroPadding2D)     │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_dwconv_left │ (None, 32, 32,    │      3,600 │ block3a_dwconv_p… │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_dwconv_rig… │ (None, 32, 32,    │      3,600 │ block3a_dwconv_p… │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_bn_left     │ (None, 32, 32,    │        576 │ block3a_dwconv_l… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_bn_right    │ (None, 32, 32,    │        576 │ block3a_dwconv_r… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_activation… │ (None, 32, 32,    │          0 │ block3a_bn_left[… │
# │ (Activation)        │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_activation… │ (None, 32, 32,    │          0 │ block3a_bn_right… │
# │ (Activation)        │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_squeeze… │ (None, 144)       │          0 │ block3a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_squeeze… │ (None, 144)       │          0 │ block3a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_reshape… │ (None, 1, 1, 144) │          0 │ block3a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_reshape… │ (None, 1, 1, 144) │          0 │ block3a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_reduce_… │ (None, 1, 1, 6)   │        870 │ block3a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_reduce_… │ (None, 1, 1, 6)   │        870 │ block3a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_expand_… │ (None, 1, 1, 144) │      1,008 │ block3a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_expand_… │ (None, 1, 1, 144) │      1,008 │ block3a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_excite_… │ (None, 32, 32,    │          0 │ block3a_activati… │
# │ (Multiply)          │ 144)              │            │ block3a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_excite_… │ (None, 32, 32,    │          0 │ block3a_activati… │
# │ (Multiply)          │ 144)              │            │ block3a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_project_co… │ (None, 32, 32,    │      5,760 │ block3a_se_excit… │
# │ (Conv2D)            │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_project_co… │ (None, 32, 32,    │      5,760 │ block3a_se_excit… │
# │ (Conv2D)            │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_project_bn… │ (None, 32, 32,    │        160 │ block3a_project_… │
# │ (BatchNormalizatio… │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_project_bn… │ (None, 32, 32,    │        160 │ block3a_project_… │
# │ (BatchNormalizatio… │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_expand_con… │ (None, 32, 32,    │      9,600 │ block3a_project_… │
# │ (Conv2D)            │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_expand_con… │ (None, 32, 32,    │      9,600 │ block3a_project_… │
# │ (Conv2D)            │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_expand_bn_… │ (None, 32, 32,    │        960 │ block3b_expand_c… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_expand_bn_… │ (None, 32, 32,    │        960 │ block3b_expand_c… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_expand_act… │ (None, 32, 32,    │          0 │ block3b_expand_b… │
# │ (Activation)        │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_expand_act… │ (None, 32, 32,    │          0 │ block3b_expand_b… │
# │ (Activation)        │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_dwconv_left │ (None, 32, 32,    │      6,000 │ block3b_expand_a… │
# │ (DepthwiseConv2D)   │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_dwconv_rig… │ (None, 32, 32,    │      6,000 │ block3b_expand_a… │
# │ (DepthwiseConv2D)   │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_bn_left     │ (None, 32, 32,    │        960 │ block3b_dwconv_l… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_bn_right    │ (None, 32, 32,    │        960 │ block3b_dwconv_r… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_activation… │ (None, 32, 32,    │          0 │ block3b_bn_left[… │
# │ (Activation)        │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_activation… │ (None, 32, 32,    │          0 │ block3b_bn_right… │
# │ (Activation)        │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_squeeze… │ (None, 240)       │          0 │ block3b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_squeeze… │ (None, 240)       │          0 │ block3b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_reshape… │ (None, 1, 1, 240) │          0 │ block3b_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_reshape… │ (None, 1, 1, 240) │          0 │ block3b_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_reduce_… │ (None, 1, 1, 10)  │      2,410 │ block3b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_reduce_… │ (None, 1, 1, 10)  │      2,410 │ block3b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_expand_… │ (None, 1, 1, 240) │      2,640 │ block3b_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_expand_… │ (None, 1, 1, 240) │      2,640 │ block3b_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_excite_… │ (None, 32, 32,    │          0 │ block3b_activati… │
# │ (Multiply)          │ 240)              │            │ block3b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_excite_… │ (None, 32, 32,    │          0 │ block3b_activati… │
# │ (Multiply)          │ 240)              │            │ block3b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_project_co… │ (None, 32, 32,    │      9,600 │ block3b_se_excit… │
# │ (Conv2D)            │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_project_co… │ (None, 32, 32,    │      9,600 │ block3b_se_excit… │
# │ (Conv2D)            │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_project_bn… │ (None, 32, 32,    │        160 │ block3b_project_… │
# │ (BatchNormalizatio… │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_project_bn… │ (None, 32, 32,    │        160 │ block3b_project_… │
# │ (BatchNormalizatio… │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_drop_left   │ (None, 32, 32,    │          0 │ block3b_project_… │
# │ (Dropout)           │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_drop_right  │ (None, 32, 32,    │          0 │ block3b_project_… │
# │ (Dropout)           │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_add_left    │ (None, 32, 32,    │          0 │ block3b_drop_lef… │
# │ (Add)               │ 40)               │            │ block3a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_add_right   │ (None, 32, 32,    │          0 │ block3b_drop_rig… │
# │ (Add)               │ 40)               │            │ block3a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_expand_con… │ (None, 32, 32,    │      9,600 │ block3b_add_left… │
# │ (Conv2D)            │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_expand_con… │ (None, 32, 32,    │      9,600 │ block3b_add_righ… │
# │ (Conv2D)            │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_expand_bn_… │ (None, 32, 32,    │        960 │ block4a_expand_c… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_expand_bn_… │ (None, 32, 32,    │        960 │ block4a_expand_c… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_expand_act… │ (None, 32, 32,    │          0 │ block4a_expand_b… │
# │ (Activation)        │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_expand_act… │ (None, 32, 32,    │          0 │ block4a_expand_b… │
# │ (Activation)        │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_dwconv_pad… │ (None, 33, 33,    │          0 │ block4a_expand_a… │
# │ (ZeroPadding2D)     │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_dwconv_pad… │ (None, 33, 33,    │          0 │ block4a_expand_a… │
# │ (ZeroPadding2D)     │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_dwconv_left │ (None, 16, 16,    │      2,160 │ block4a_dwconv_p… │
# │ (DepthwiseConv2D)   │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_dwconv_rig… │ (None, 16, 16,    │      2,160 │ block4a_dwconv_p… │
# │ (DepthwiseConv2D)   │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_bn_left     │ (None, 16, 16,    │        960 │ block4a_dwconv_l… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_bn_right    │ (None, 16, 16,    │        960 │ block4a_dwconv_r… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_activation… │ (None, 16, 16,    │          0 │ block4a_bn_left[… │
# │ (Activation)        │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_activation… │ (None, 16, 16,    │          0 │ block4a_bn_right… │
# │ (Activation)        │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_squeeze… │ (None, 240)       │          0 │ block4a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_squeeze… │ (None, 240)       │          0 │ block4a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_reshape… │ (None, 1, 1, 240) │          0 │ block4a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_reshape… │ (None, 1, 1, 240) │          0 │ block4a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_reduce_… │ (None, 1, 1, 10)  │      2,410 │ block4a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_reduce_… │ (None, 1, 1, 10)  │      2,410 │ block4a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_expand_… │ (None, 1, 1, 240) │      2,640 │ block4a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_expand_… │ (None, 1, 1, 240) │      2,640 │ block4a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_excite_… │ (None, 16, 16,    │          0 │ block4a_activati… │
# │ (Multiply)          │ 240)              │            │ block4a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_excite_… │ (None, 16, 16,    │          0 │ block4a_activati… │
# │ (Multiply)          │ 240)              │            │ block4a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_project_co… │ (None, 16, 16,    │     19,200 │ block4a_se_excit… │
# │ (Conv2D)            │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_project_co… │ (None, 16, 16,    │     19,200 │ block4a_se_excit… │
# │ (Conv2D)            │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_project_bn… │ (None, 16, 16,    │        320 │ block4a_project_… │
# │ (BatchNormalizatio… │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_project_bn… │ (None, 16, 16,    │        320 │ block4a_project_… │
# │ (BatchNormalizatio… │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_expand_con… │ (None, 16, 16,    │     38,400 │ block4a_project_… │
# │ (Conv2D)            │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_expand_con… │ (None, 16, 16,    │     38,400 │ block4a_project_… │
# │ (Conv2D)            │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_expand_bn_… │ (None, 16, 16,    │      1,920 │ block4b_expand_c… │
# │ (BatchNormalizatio… │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_expand_bn_… │ (None, 16, 16,    │      1,920 │ block4b_expand_c… │
# │ (BatchNormalizatio… │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_expand_act… │ (None, 16, 16,    │          0 │ block4b_expand_b… │
# │ (Activation)        │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_expand_act… │ (None, 16, 16,    │          0 │ block4b_expand_b… │
# │ (Activation)        │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_dwconv_left │ (None, 16, 16,    │      4,320 │ block4b_expand_a… │
# │ (DepthwiseConv2D)   │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_dwconv_rig… │ (None, 16, 16,    │      4,320 │ block4b_expand_a… │
# │ (DepthwiseConv2D)   │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_bn_left     │ (None, 16, 16,    │      1,920 │ block4b_dwconv_l… │
# │ (BatchNormalizatio… │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_bn_right    │ (None, 16, 16,    │      1,920 │ block4b_dwconv_r… │
# │ (BatchNormalizatio… │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_activation… │ (None, 16, 16,    │          0 │ block4b_bn_left[… │
# │ (Activation)        │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_activation… │ (None, 16, 16,    │          0 │ block4b_bn_right… │
# │ (Activation)        │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_squeeze… │ (None, 480)       │          0 │ block4b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_squeeze… │ (None, 480)       │          0 │ block4b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_reshape… │ (None, 1, 1, 480) │          0 │ block4b_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_reshape… │ (None, 1, 1, 480) │          0 │ block4b_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_reduce_… │ (None, 1, 1, 20)  │      9,620 │ block4b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_reduce_… │ (None, 1, 1, 20)  │      9,620 │ block4b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_expand_… │ (None, 1, 1, 480) │     10,080 │ block4b_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_expand_… │ (None, 1, 1, 480) │     10,080 │ block4b_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_excite_… │ (None, 16, 16,    │          0 │ block4b_activati… │
# │ (Multiply)          │ 480)              │            │ block4b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_excite_… │ (None, 16, 16,    │          0 │ block4b_activati… │
# │ (Multiply)          │ 480)              │            │ block4b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_project_co… │ (None, 16, 16,    │     38,400 │ block4b_se_excit… │
# ...
# │ block7a_expand_con… │ (None, 8, 8,      │    221,184 │ block6d_add_righ… │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_expand_bn_… │ (None, 8, 8,      │      4,608 │ block7a_expand_c… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_expand_bn_… │ (None, 8, 8,      │      4,608 │ block7a_expand_c… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_expand_act… │ (None, 8, 8,      │          0 │ block7a_expand_b… │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_expand_act… │ (None, 8, 8,      │          0 │ block7a_expand_b… │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_dwconv_left │ (None, 8, 8,      │     10,368 │ block7a_expand_a… │
# │ (DepthwiseConv2D)   │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_dwconv_rig… │ (None, 8, 8,      │     10,368 │ block7a_expand_a… │
# │ (DepthwiseConv2D)   │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_bn_left     │ (None, 8, 8,      │      4,608 │ block7a_dwconv_l… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_bn_right    │ (None, 8, 8,      │      4,608 │ block7a_dwconv_r… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_activation… │ (None, 8, 8,      │          0 │ block7a_bn_left[… │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_activation… │ (None, 8, 8,      │          0 │ block7a_bn_right… │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_se_squeeze… │ (None, 1152)      │          0 │ block7a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_se_squeeze… │ (None, 1152)      │          0 │ block7a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_se_reshape… │ (None, 1, 1,      │          0 │ block7a_se_squee… │
# │ (Reshape)           │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_se_reshape… │ (None, 1, 1,      │          0 │ block7a_se_squee… │
# │ (Reshape)           │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_se_reduce_… │ (None, 1, 1, 48)  │     55,344 │ block7a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_se_reduce_… │ (None, 1, 1, 48)  │     55,344 │ block7a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_se_expand_… │ (None, 1, 1,      │     56,448 │ block7a_se_reduc… │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_se_expand_… │ (None, 1, 1,      │     56,448 │ block7a_se_reduc… │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_se_excite_… │ (None, 8, 8,      │          0 │ block7a_activati… │
# │ (Multiply)          │ 1152)             │            │ block7a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_se_excite_… │ (None, 8, 8,      │          0 │ block7a_activati… │
# │ (Multiply)          │ 1152)             │            │ block7a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_project_co… │ (None, 8, 8, 320) │    368,640 │ block7a_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_project_co… │ (None, 8, 8, 320) │    368,640 │ block7a_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_project_bn… │ (None, 8, 8, 320) │      1,280 │ block7a_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_project_bn… │ (None, 8, 8, 320) │      1,280 │ block7a_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ top_conv_left       │ (None, 8, 8,      │    409,600 │ block7a_project_… │
# │ (Conv2D)            │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ top_conv_right      │ (None, 8, 8,      │    409,600 │ block7a_project_… │
# │ (Conv2D)            │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ top_bn_left         │ (None, 8, 8,      │      5,120 │ top_conv_left[0]… │
# │ (BatchNormalizatio… │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ top_bn_right        │ (None, 8, 8,      │      5,120 │ top_conv_right[0… │
# │ (BatchNormalizatio… │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ top_activation_left │ (None, 8, 8,      │          0 │ top_bn_left[0][0] │
# │ (Activation)        │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ top_activation_rig… │ (None, 8, 8,      │          0 │ top_bn_right[0][… │
# │ (Activation)        │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ feature_map_combine │ (None, 8, 8,      │          0 │ top_activation_l… │
# │ (Concatenate)       │ 2560)             │            │ top_activation_r… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ feature_map_refiner │ (None, 8, 8,      │ 47,187,968 │ feature_map_comb… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 8, 8,      │      8,192 │ feature_map_refi… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 8, 8,      │          0 │ batch_normalizat… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_16          │ (None, 16, 16,    │ 18,875,392 │ activation[0][0]  │
# │ (Conv2DTranspose)   │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ skip_concat_16      │ (None, 16, 16,    │          0 │ decoder_16[0][0], │
# │ (Concatenate)       │ 2368)             │            │ block6a_expand_a… │
# │                     │                   │            │ block6a_expand_a… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_refine_16   │ (None, 16, 16,    │ 21,824,512 │ skip_concat_16[0… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      4,096 │ decoder_refine_1… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_32          │ (None, 32, 32,    │  4,719,104 │ activation_1[0][… │
# │ (Conv2DTranspose)   │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ skip_concat_32      │ (None, 32, 32,    │          0 │ decoder_32[0][0], │
# │ (Concatenate)       │ 992)              │            │ block4a_expand_a… │
# │                     │                   │            │ block4a_expand_a… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_refine_32   │ (None, 32, 32,    │  4,571,648 │ skip_concat_32[0… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      2,048 │ decoder_refine_3… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_64          │ (None, 64, 64,    │  1,179,904 │ activation_2[0][… │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ skip_concat_64      │ (None, 64, 64,    │          0 │ decoder_64[0][0], │
# │ (Concatenate)       │ 544)              │            │ block3a_expand_a… │
# │                     │                   │            │ block3a_expand_a… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_refine_64   │ (None, 64, 64,    │  1,253,632 │ skip_concat_64[0… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │      1,024 │ decoder_refine_6… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_128         │ (None, 128, 128,  │    295,040 │ activation_3[0][… │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ skip_concat_128     │ (None, 128, 128,  │          0 │ decoder_128[0][0… │
# │ (Concatenate)       │ 320)              │            │ block2a_expand_a… │
# │                     │                   │            │ block2a_expand_a… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_refine_128  │ (None, 128, 128,  │    368,768 │ skip_concat_128[… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        512 │ decoder_refine_1… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_256         │ (None, 256, 256,  │     73,792 │ activation_4[0][… │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ skip_concat_256     │ (None, 256, 256,  │          0 │ decoder_256[0][0… │
# │ (Concatenate)       │ 70)               │            │ rescaling_1_left… │
# │                     │                   │            │ rescaling_3_righ… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_refine_256  │ (None, 256, 256,  │     40,384 │ skip_concat_256[… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        256 │ decoder_refine_2… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ opt_refiner_32      │ (None, 256, 256,  │     18,464 │ activation_5[0][… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        128 │ opt_refiner_32[0… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ opt_refiner_16      │ (None, 256, 256,  │      4,624 │ activation_6[0][… │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ opt_refiner_16[0… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fused_output        │ (None, 256, 256,  │         51 │ activation_7[0][… │
# │ (Conv2D)            │ 3)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 108,528,745 (414.00 MB)
#  Trainable params: 108,436,539 (413.65 MB)
#  Non-trainable params: 92,206 (360.19 KB)

# %% [markdown]
# ### Loss Function and Evaluation Metrics

# %%
import tensorflow as tf
import numpy as np

def fusion_loss(y_true, y_pred):
    """
    Computes: RGB L1_Loss + 0.5 * Luminance_Edge_Loss
    """
    # 1. Base L1 Loss (Color + Structure)
    # Applies to all 3 RGB channels to guarantee pixel-perfect color reconstruction
    l1_loss = tf.reduce_mean(tf.abs(y_true - y_pred))
    
    # 2. Isolate Structure for Edge Detection
    # tf.image.rgb_to_grayscale mathematically extracts the Y (Luminance) channel.
    # Shape converts from [batch, h, w, 3] to [batch, h, w, 1]
    y_true_luma = tf.image.rgb_to_grayscale(y_true)
    y_pred_luma = tf.image.rgb_to_grayscale(y_pred)
    
    # 3. Edge Loss using Sobel Filters strictly on the Luminance channel
    # This prevents the network from hallucinating edge artifacts inside the smooth PET thermal clouds
    sobel_true = tf.image.sobel_edges(y_true_luma)
    sobel_pred = tf.image.sobel_edges(y_pred_luma)
    
    edge_loss = tf.reduce_mean(tf.abs(sobel_true - sobel_pred))
    
    # 4. Combine them
    total_loss = l1_loss + (0.5 * edge_loss)
    
    return total_loss
    

# 1. PSNR (Peak Signal-to-Noise Ratio)
def psnr(y_true, y_pred):
    return tf.image.psnr(y_true, y_pred, max_val=1.0)

# 2. SSIM (Structural Similarity Index Measure)
def ssim(y_true, y_pred):
    return tf.image.ssim(y_true, y_pred, max_val=1.0)

# 3. Mutual Information (MI)
def numpy_mutual_information(y_true, y_pred):
    """
    Standard numpy implementation of Mutual Information using a 2D joint histogram.
    """
    # It converts the entire RGB matrix into a continuous 1D distribution array.
    y_true_flat = y_true.flatten()
    y_pred_flat = y_pred.flatten()
    
    # Calculate the 2D histogram (using 100 bins for continuous 0.0-1.0 values)
    hist_2d, _, _ = np.histogram2d(y_true_flat, y_pred_flat, bins=100)
    
    # Convert histogram counts to probabilities
    pxy = hist_2d / float(np.sum(hist_2d))
    px = np.sum(pxy, axis=1)
    py = np.sum(pxy, axis=0)
    px_py = px[:, None] * py[None, :]
    
    # Calculate MI only where probabilities are non-zero to avoid log(0)
    non_zeros = pxy > 0
    mi = np.sum(pxy[non_zeros] * np.log(pxy[non_zeros] / px_py[non_zeros]))
    
    return np.float32(mi)

# %% [markdown]
# ## Warm Up Training

# %% [markdown]
# ### Model Compilation

# %%
from tensorflow.keras.optimizers import Adam

# Freezing Encoder
left_encoder.trainable = False
right_encoder.trainable = False

# Compile the model
fusion_model.compile(
    optimizer=Adam(learning_rate=1e-3),
    loss=fusion_loss,
    metrics=[psnr]
)

# %% [markdown]
# ### Callbacks

# %%
from tensorflow.keras.callbacks import EarlyStopping

# Stops the training if the monitor metrics doesnt improves in specific patience epochs
early_stopping = EarlyStopping(monitor='val_loss', patience=10, min_delta=1e-3, restore_best_weights=True)

# %% [markdown]
# ### Training

# %%
train_steps = len(X1_train) // batch_size

print(f"Batch Size: {batch_size}")
print(f"Calculated Train Steps: {train_steps}")
print('')

print("Starting Warm Up...")
history_warmup = fusion_model.fit(
    train_fusion_gen,
    steps_per_epoch=train_steps,
    epochs=100,
    validation_data=([X1_val, X2_val], y_val),
    callbacks=[early_stopping]
)
# Out:
# Batch Size: 4
# Calculated Train Steps: 32
#
# Starting Warm Up...
# Epoch 1/100
# I0000 00:00:1783092844.143166      70 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 96s 1s/step - loss: 0.2249 - psnr: 14.2698 - val_loss: 0.5507 - val_psnr: 5.8775
# Epoch 2/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 188ms/step - loss: 0.1315 - psnr: 18.3909 - val_loss: 0.1869 - val_psnr: 16.1783
# Epoch 3/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 179ms/step - loss: 0.0963 - psnr: 21.3607 - val_loss: 0.0879 - val_psnr: 23.0837
# Epoch 4/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.0739 - psnr: 23.8686 - val_loss: 0.0685 - val_psnr: 25.0839
# Epoch 5/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 170ms/step - loss: 0.0581 - psnr: 26.2323 - val_loss: 0.0561 - val_psnr: 26.7423
# Epoch 6/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 176ms/step - loss: 0.0478 - psnr: 28.1793 - val_loss: 0.0549 - val_psnr: 26.9848
# Epoch 7/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 176ms/step - loss: 0.0422 - psnr: 29.4838 - val_loss: 0.0473 - val_psnr: 27.7780
# Epoch 8/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 185ms/step - loss: 0.0368 - psnr: 30.6896 - val_loss: 0.0414 - val_psnr: 29.0365
# Epoch 9/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 140ms/step - loss: 0.0351 - psnr: 31.0271 - val_loss: 0.0435 - val_psnr: 28.4433
# Epoch 10/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 173ms/step - loss: 0.0327 - psnr: 31.6905 - val_loss: 0.0428 - val_psnr: 28.1087
# Epoch 11/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 189ms/step - loss: 0.0316 - psnr: 31.8925 - val_loss: 0.0339 - val_psnr: 30.5709
# Epoch 12/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 147ms/step - loss: 0.0268 - psnr: 33.3223 - val_loss: 0.0351 - val_psnr: 30.1121
# Epoch 13/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 194ms/step - loss: 0.0244 - psnr: 34.0924 - val_loss: 0.0315 - val_psnr: 30.7717
# Epoch 14/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 167ms/step - loss: 0.0244 - psnr: 33.8422 - val_loss: 0.0274 - val_psnr: 32.1515
# Epoch 15/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 149ms/step - loss: 0.0255 - psnr: 33.2338 - val_loss: 0.0312 - val_psnr: 30.6087
# Epoch 16/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 167ms/step - loss: 0.0235 - psnr: 34.0435 - val_loss: 0.0299 - val_psnr: 30.9177
# Epoch 17/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 167ms/step - loss: 0.0221 - psnr: 34.5873 - val_loss: 0.0289 - val_psnr: 31.1241
# Epoch 18/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 196ms/step - loss: 0.0210 - psnr: 34.8753 - val_loss: 0.0222 - val_psnr: 33.6645
# Epoch 19/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 147ms/step - loss: 0.0203 - psnr: 35.0833 - val_loss: 0.0235 - val_psnr: 33.1086
# Epoch 20/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 167ms/step - loss: 0.0213 - psnr: 34.4779 - val_loss: 0.0214 - val_psnr: 34.4244
# Epoch 21/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 172ms/step - loss: 0.0193 - psnr: 35.5215 - val_loss: 0.0247 - val_psnr: 32.5422
# Epoch 22/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 176ms/step - loss: 0.0207 - psnr: 34.7004 - val_loss: 0.0223 - val_psnr: 33.6665
# Epoch 23/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 194ms/step - loss: 0.0188 - psnr: 35.8714 - val_loss: 0.0186 - val_psnr: 35.2900
# Epoch 24/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 149ms/step - loss: 0.0198 - psnr: 34.8670 - val_loss: 0.0239 - val_psnr: 32.8329
# Epoch 25/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 176ms/step - loss: 0.0180 - psnr: 35.8984 - val_loss: 0.0226 - val_psnr: 32.6918
# Epoch 26/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 175ms/step - loss: 0.0184 - psnr: 35.5186 - val_loss: 0.0183 - val_psnr: 34.8818
# Epoch 27/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 166ms/step - loss: 0.0189 - psnr: 35.2825 - val_loss: 0.0199 - val_psnr: 34.7057
# Epoch 28/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 169ms/step - loss: 0.0168 - psnr: 36.2970 - val_loss: 0.0204 - val_psnr: 33.6847
# Epoch 29/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 197ms/step - loss: 0.0169 - psnr: 36.3663 - val_loss: 0.0170 - val_psnr: 35.8678
# Epoch 30/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 151ms/step - loss: 0.0168 - psnr: 36.3561 - val_loss: 0.0165 - val_psnr: 36.2950
# Epoch 31/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 178ms/step - loss: 0.0180 - psnr: 35.8522 - val_loss: 0.0192 - val_psnr: 34.4955
# Epoch 32/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 169ms/step - loss: 0.0170 - psnr: 36.2668 - val_loss: 0.0162 - val_psnr: 36.3409
# Epoch 33/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.0163 - psnr: 36.5257 - val_loss: 0.0161 - val_psnr: 36.1291
# Epoch 34/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 181ms/step - loss: 0.0157 - psnr: 36.7740 - val_loss: 0.0177 - val_psnr: 34.8720
# Epoch 35/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 193ms/step - loss: 0.0139 - psnr: 37.9460 - val_loss: 0.0146 - val_psnr: 36.4279
# Epoch 36/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 147ms/step - loss: 0.0154 - psnr: 36.7410 - val_loss: 0.0148 - val_psnr: 36.6906
# Epoch 37/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 178ms/step - loss: 0.0159 - psnr: 36.6520 - val_loss: 0.0172 - val_psnr: 35.6144
# Epoch 38/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 163ms/step - loss: 0.0158 - psnr: 36.3815 - val_loss: 0.0165 - val_psnr: 35.5173
# Epoch 39/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 170ms/step - loss: 0.0160 - psnr: 36.6338 - val_loss: 0.0160 - val_psnr: 36.1837
# Epoch 40/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 175ms/step - loss: 0.0152 - psnr: 36.8498 - val_loss: 0.0163 - val_psnr: 36.0243
# Epoch 41/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 166ms/step - loss: 0.0139 - psnr: 37.7028 - val_loss: 0.0151 - val_psnr: 36.8143
# Epoch 42/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 170ms/step - loss: 0.0141 - psnr: 37.6809 - val_loss: 0.0158 - val_psnr: 36.1449
# Epoch 43/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 179ms/step - loss: 0.0146 - psnr: 37.2219 - val_loss: 0.0149 - val_psnr: 36.8596
# Epoch 44/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 178ms/step - loss: 0.0143 - psnr: 37.5434 - val_loss: 0.0155 - val_psnr: 36.1417
# Epoch 45/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 170ms/step - loss: 0.0151 - psnr: 36.7630 - val_loss: 0.0236 - val_psnr: 32.3793

# %% [markdown]
# ## Fine Tuning

# %% [markdown]
# ### Model Compilation

# %%
from tensorflow.keras.optimizers import Adam

# Define how much last layers will be fine-tuned
percent_of_layers_to_train = 25
to_be_trained_left = int((percent_of_layers_to_train/100)*len(left_encoder.layers))
to_be_trained_right = int((percent_of_layers_to_train/100)*len(right_encoder.layers))

print(f"Trainable Layers for Left Stream : {to_be_trained_left}")
print(f"Trainable Layers for Right Stream : {to_be_trained_right}")

for layer in left_encoder.layers[:-to_be_trained_left]:
    layer.trainable = False

for layer in left_encoder.layers[-to_be_trained_left:]:
    layer.trainable = True

for layer in right_encoder.layers[:-to_be_trained_right]:
    layer.trainable = False

for layer in right_encoder.layers[-to_be_trained_right:]:
    layer.trainable = True


# Compile the model
fusion_model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss=fusion_loss,
    metrics=[psnr]
)
# Out:
# Trainable Layers for Left Stream : 59
# Trainable Layers for Right Stream : 59

# %% [markdown]
# ### Callbacks

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping

# Saves the model automatically whenever the validation loss hits a new all-time low
model_checkpoint = ModelCheckpoint(filepath='/kaggle/working/fusion_model_best.keras', monitor='val_loss', save_best_only=True, mode='min', verbose=0)

# Reduces the learning rate by multiplying with the defined factor if the monitor metrics doesnt improves in specific patience epochs
lr_schedule = ReduceLROnPlateau(monitor='val_loss', factor=0.75, patience=5, min_lr=1e-6)

# Stops the training if the monitor metrics doesnt improves in specific patience epochs
early_stopping = EarlyStopping(monitor='val_loss', patience=30, min_delta=1e-4, restore_best_weights=True)

# %% [markdown]
# ### Training

# %%
# Calculate Steps
train_steps = len(X1_train) // batch_size

print(f"Batch Size: {batch_size}")
print(f"Calculated Train Steps: {train_steps}")
print('')

# The Training Loop
print("Starting Fine Tunning...")
history_finetune = fusion_model.fit(
    train_fusion_gen,
    steps_per_epoch=train_steps,
    epochs=500,
    validation_data=([X1_val, X2_val], y_val),
    callbacks=[model_checkpoint, lr_schedule, early_stopping]
)
# Out:
# Batch Size: 4
# Calculated Train Steps: 32
#
# Starting Fine Tunning...
# Epoch 1/500
# 2026-07-03 15:39:31.279364: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-07-03 15:39:31.484700: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 97s 858ms/step - loss: 0.0131 - psnr: 38.1824 - val_loss: 0.0140 - val_psnr: 36.6449 - learning_rate: 1.0000e-04
# Epoch 2/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 426ms/step - loss: 0.0142 - psnr: 37.3358 - val_loss: 0.0131 - val_psnr: 37.3199 - learning_rate: 1.0000e-04
# Epoch 3/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 432ms/step - loss: 0.0134 - psnr: 38.0196 - val_loss: 0.0125 - val_psnr: 37.7575 - learning_rate: 1.0000e-04
# Epoch 4/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 157ms/step - loss: 0.0140 - psnr: 37.5616 - val_loss: 0.0127 - val_psnr: 37.8078 - learning_rate: 1.0000e-04
# Epoch 5/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 186ms/step - loss: 0.0136 - psnr: 37.5201 - val_loss: 0.0126 - val_psnr: 37.9468 - learning_rate: 1.0000e-04
# Epoch 6/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 189ms/step - loss: 0.0124 - psnr: 38.7440 - val_loss: 0.0128 - val_psnr: 37.8765 - learning_rate: 1.0000e-04
# Epoch 7/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 423ms/step - loss: 0.0133 - psnr: 37.8671 - val_loss: 0.0122 - val_psnr: 37.9121 - learning_rate: 1.0000e-04
# Epoch 8/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 145ms/step - loss: 0.0136 - psnr: 38.1633 - val_loss: 0.0125 - val_psnr: 38.0110 - learning_rate: 1.0000e-04
# Epoch 9/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 151ms/step - loss: 0.0126 - psnr: 38.6263 - val_loss: 0.0127 - val_psnr: 37.8481 - learning_rate: 1.0000e-04
# Epoch 10/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 173ms/step - loss: 0.0127 - psnr: 38.3352 - val_loss: 0.0130 - val_psnr: 37.7368 - learning_rate: 1.0000e-04
# Epoch 11/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 429ms/step - loss: 0.0134 - psnr: 37.9112 - val_loss: 0.0120 - val_psnr: 38.2403 - learning_rate: 1.0000e-04
# Epoch 12/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 145ms/step - loss: 0.0124 - psnr: 38.5353 - val_loss: 0.0124 - val_psnr: 38.0268 - learning_rate: 1.0000e-04
# Epoch 13/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 419ms/step - loss: 0.0118 - psnr: 39.0550 - val_loss: 0.0119 - val_psnr: 38.2172 - learning_rate: 1.0000e-04
# Epoch 14/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 145ms/step - loss: 0.0131 - psnr: 38.1171 - val_loss: 0.0133 - val_psnr: 37.6121 - learning_rate: 1.0000e-04
# Epoch 15/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 145ms/step - loss: 0.0119 - psnr: 39.1285 - val_loss: 0.0121 - val_psnr: 38.1478 - learning_rate: 1.0000e-04
# Epoch 16/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 143ms/step - loss: 0.0123 - psnr: 38.8390 - val_loss: 0.0122 - val_psnr: 38.0586 - learning_rate: 1.0000e-04
# Epoch 17/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 144ms/step - loss: 0.0124 - psnr: 38.5918 - val_loss: 0.0123 - val_psnr: 38.0065 - learning_rate: 1.0000e-04
# Epoch 18/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 163ms/step - loss: 0.0132 - psnr: 38.0584 - val_loss: 0.0128 - val_psnr: 37.8199 - learning_rate: 1.0000e-04
# Epoch 19/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 425ms/step - loss: 0.0124 - psnr: 38.4904 - val_loss: 0.0117 - val_psnr: 38.2114 - learning_rate: 7.5000e-05
# Epoch 20/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 145ms/step - loss: 0.0120 - psnr: 38.7288 - val_loss: 0.0123 - val_psnr: 37.6422 - learning_rate: 7.5000e-05
# Epoch 21/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 144ms/step - loss: 0.0124 - psnr: 38.6525 - val_loss: 0.0117 - val_psnr: 38.4462 - learning_rate: 7.5000e-05
# Epoch 22/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 144ms/step - loss: 0.0109 - psnr: 39.6181 - val_loss: 0.0117 - val_psnr: 38.2616 - learning_rate: 7.5000e-05
# Epoch 23/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 144ms/step - loss: 0.0125 - psnr: 38.4178 - val_loss: 0.0123 - val_psnr: 38.0978 - learning_rate: 7.5000e-05
# Epoch 24/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 401ms/step - loss: 0.0113 - psnr: 39.1881 - val_loss: 0.0114 - val_psnr: 38.4099 - learning_rate: 7.5000e-05
# Epoch 25/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 12s 384ms/step - loss: 0.0105 - psnr: 39.9252 - val_loss: 0.0113 - val_psnr: 38.4764 - learning_rate: 7.5000e-05
# Epoch 26/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 144ms/step - loss: 0.0130 - psnr: 38.1765 - val_loss: 0.0116 - val_psnr: 38.3228 - learning_rate: 7.5000e-05
# Epoch 27/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 146ms/step - loss: 0.0110 - psnr: 39.4692 - val_loss: 0.0116 - val_psnr: 38.3907 - learning_rate: 7.5000e-05
# Epoch 28/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 143ms/step - loss: 0.0117 - psnr: 38.8226 - val_loss: 0.0116 - val_psnr: 38.2023 - learning_rate: 7.5000e-05
# Epoch 29/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 143ms/step - loss: 0.0123 - psnr: 38.5334 - val_loss: 0.0113 - val_psnr: 38.3111 - learning_rate: 7.5000e-05
# Epoch 30/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 144ms/step - loss: 0.0114 - psnr: 39.1284 - val_loss: 0.0114 - val_psnr: 38.4625 - learning_rate: 5.6250e-05
# Epoch 31/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 144ms/step - loss: 0.0121 - psnr: 38.6280 - val_loss: 0.0115 - val_psnr: 38.2034 - learning_rate: 5.6250e-05
# Epoch 32/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 399ms/step - loss: 0.0115 - psnr: 39.0258 - val_loss: 0.0111 - val_psnr: 38.4672 - learning_rate: 5.6250e-05
# Epoch 33/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 145ms/step - loss: 0.0104 - psnr: 40.0783 - val_loss: 0.0111 - val_psnr: 38.3130 - learning_rate: 5.6250e-05
# Epoch 34/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 143ms/step - loss: 0.0109 - psnr: 39.5947 - val_loss: 0.0118 - val_psnr: 38.3452 - learning_rate: 5.6250e-05
# Epoch 35/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 143ms/step - loss: 0.0118 - psnr: 38.9169 - val_loss: 0.0113 - val_psnr: 38.3519 - learning_rate: 5.6250e-05
# Epoch 36/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 12s 376ms/step - loss: 0.0114 - psnr: 39.1775 - val_loss: 0.0110 - val_psnr: 38.4888 - learning_rate: 5.6250e-05
# Epoch 37/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 144ms/step - loss: 0.0107 - psnr: 39.7710 - val_loss: 0.0111 - val_psnr: 38.5311 - learning_rate: 5.6250e-05
# Epoch 38/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 144ms/step - loss: 0.0107 - psnr: 39.8049 - val_loss: 0.0114 - val_psnr: 38.4642 - learning_rate: 4.2188e-05
# Epoch 39/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 144ms/step - loss: 0.0113 - psnr: 39.1465 - val_loss: 0.0112 - val_psnr: 38.4727 - learning_rate: 4.2188e-05
# Epoch 40/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 12s 398ms/step - loss: 0.0105 - psnr: 40.0355 - val_loss: 0.0109 - val_psnr: 38.6041 - learning_rate: 4.2188e-05
# Epoch 41/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 146ms/step - loss: 0.0112 - psnr: 39.2203 - val_loss: 0.0111 - val_psnr: 38.4879 - learning_rate: 4.2188e-05
# Epoch 42/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 144ms/step - loss: 0.0107 - psnr: 39.6845 - val_loss: 0.0112 - val_psnr: 38.2614 - learning_rate: 4.2188e-05
# Epoch 43/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 144ms/step - loss: 0.0108 - psnr: 39.6824 - val_loss: 0.0110 - val_psnr: 38.5365 - learning_rate: 4.2188e-05
# Epoch 44/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 144ms/step - loss: 0.0108 - psnr: 39.6638 - val_loss: 0.0111 - val_psnr: 38.4131 - learning_rate: 4.2188e-05
# Epoch 45/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 144ms/step - loss: 0.0106 - psnr: 39.7706 - val_loss: 0.0114 - val_psnr: 38.4550 - learning_rate: 4.2188e-05
# Epoch 46/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 144ms/step - loss: 0.0107 - psnr: 39.7719 - val_loss: 0.0110 - val_psnr: 38.6603 - learning_rate: 3.1641e-05
# Epoch 47/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 144ms/step - loss: 0.0110 - psnr: 39.5056 - val_loss: 0.0111 - val_psnr: 38.5374 - learning_rate: 3.1641e-05
# Epoch 48/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 144ms/step - loss: 0.0110 - psnr: 39.6451 - val_loss: 0.0112 - val_psnr: 38.4711 - learning_rate: 3.1641e-05
# Epoch 49/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 167ms/step - loss: 0.0109 - psnr: 39.7424 - val_loss: 0.0111 - val_psnr: 38.6164 - learning_rate: 3.1641e-05
# Epoch 50/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 182ms/step - loss: 0.0104 - psnr: 40.0077 - val_loss: 0.0112 - val_psnr: 38.6166 - learning_rate: 3.1641e-05
# Epoch 51/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 178ms/step - loss: 0.0103 - psnr: 40.1741 - val_loss: 0.0110 - val_psnr: 38.4364 - learning_rate: 2.3730e-05
# Epoch 52/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 177ms/step - loss: 0.0102 - psnr: 40.2119 - val_loss: 0.0113 - val_psnr: 38.2215 - learning_rate: 2.3730e-05
# Epoch 53/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 177ms/step - loss: 0.0101 - psnr: 40.2114 - val_loss: 0.0110 - val_psnr: 38.4544 - learning_rate: 2.3730e-05
# Epoch 54/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 173ms/step - loss: 0.0107 - psnr: 39.8817 - val_loss: 0.0111 - val_psnr: 38.4277 - learning_rate: 2.3730e-05
# Epoch 55/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 172ms/step - loss: 0.0107 - psnr: 39.8810 - val_loss: 0.0110 - val_psnr: 38.4574 - learning_rate: 2.3730e-05
# Epoch 56/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 171ms/step - loss: 0.0100 - psnr: 40.2709 - val_loss: 0.0111 - val_psnr: 38.4079 - learning_rate: 1.7798e-05
# Epoch 57/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 178ms/step - loss: 0.0113 - psnr: 39.1937 - val_loss: 0.0110 - val_psnr: 38.5684 - learning_rate: 1.7798e-05
# Epoch 58/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.0107 - psnr: 39.8412 - val_loss: 0.0110 - val_psnr: 38.5130 - learning_rate: 1.7798e-05
# Epoch 59/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 181ms/step - loss: 0.0107 - psnr: 39.8853 - val_loss: 0.0110 - val_psnr: 38.5450 - learning_rate: 1.7798e-05
# Epoch 60/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 176ms/step - loss: 0.0101 - psnr: 40.2474 - val_loss: 0.0110 - val_psnr: 38.4218 - learning_rate: 1.7798e-05
# Epoch 61/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 179ms/step - loss: 0.0104 - psnr: 40.1276 - val_loss: 0.0110 - val_psnr: 38.4455 - learning_rate: 1.3348e-05
# Epoch 62/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 409ms/step - loss: 0.0102 - psnr: 40.1479 - val_loss: 0.0109 - val_psnr: 38.5877 - learning_rate: 1.3348e-05
# Epoch 63/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 144ms/step - loss: 0.0109 - psnr: 39.6687 - val_loss: 0.0110 - val_psnr: 38.4740 - learning_rate: 1.3348e-05
# Epoch 64/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 145ms/step - loss: 0.0100 - psnr: 40.2402 - val_loss: 0.0110 - val_psnr: 38.4588 - learning_rate: 1.3348e-05
# Epoch 65/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 144ms/step - loss: 0.0106 - psnr: 39.7121 - val_loss: 0.0111 - val_psnr: 38.5476 - learning_rate: 1.3348e-05
# Epoch 66/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 144ms/step - loss: 0.0098 - psnr: 40.5707 - val_loss: 0.0109 - val_psnr: 38.5676 - learning_rate: 1.0011e-05
# Epoch 67/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 144ms/step - loss: 0.0106 - psnr: 39.9862 - val_loss: 0.0109 - val_psnr: 38.5680 - learning_rate: 1.0011e-05
# Epoch 68/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 163ms/step - loss: 0.0103 - psnr: 39.9889 - val_loss: 0.0110 - val_psnr: 38.5192 - learning_rate: 1.0011e-05
# Epoch 69/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 171ms/step - loss: 0.0107 - psnr: 39.6820 - val_loss: 0.0110 - val_psnr: 38.5434 - learning_rate: 1.0011e-05
# Epoch 70/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 173ms/step - loss: 0.0099 - psnr: 40.4333 - val_loss: 0.0110 - val_psnr: 38.5171 - learning_rate: 1.0011e-05

# %% [markdown]
# ## Result and Visualization

# %% [markdown]
# ### Final Result on TestSet

# %%
# Final Result

print("Running predictions...")

# Pass the dual-stream inputs as a Python list
y_pred_all = fusion_model.predict([X1_test, X2_test], batch_size=batch_size)
y_pred_all = np.clip(y_pred_all, 0.0, 1.0) # Ensure strict 0-1 bounds

# Convert numpy arrays to tensors for the TF functions
y_true_tensor = tf.constant(y_test, dtype=tf.float32)
y_pred_tensor = tf.constant(y_pred_all, dtype=tf.float32)

# fusion_loss naturally returns a single mean value
final_loss = fusion_loss(y_true_tensor, y_pred_tensor).numpy()

# psnr and ssim return an array of scores (one for each image in the array). 
# use tf.reduce_mean to average them into a single final score.
final_psnr = tf.reduce_mean(psnr(y_true_tensor, y_pred_tensor)).numpy()
final_ssim = tf.reduce_mean(ssim(y_true_tensor, y_pred_tensor)).numpy()

final_mi = numpy_mutual_information(y_test, y_pred_all)

# Print Results
print("\n" + "="*40)
print("          FINAL TEST RESULTS")
print("="*40)
print(f"Test Loss (L1 + Edge) : {final_loss:.5f}")
print(f"Test PSNR             : {final_psnr:.4f} dB")
print(f"Test SSIM             : {final_ssim:.4f}")
print(f"Test Mutual Info (MI) : {final_mi:.4f}")
print("="*40)
# Out:
# Running predictions...
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step
#
# ========================================
#           FINAL TEST RESULTS
# ========================================
# Test Loss (L1 + Edge) : 0.01060
# Test PSNR             : 38.9669 dB
# Test SSIM             : 0.9939
# Test Mutual Info (MI) : 1.8127
# ========================================

# %% [markdown]
# ### Visualizion of Final Fused Image

# %%
def show_fusion_results(x1_batch, x2_batch, fused_batch, num_images=4):
    """
    Plots the X1, X2, and Fused images side-by-side.
    """
    # Ensure we don't try to plot more images than exist in the batch
    num_images = min(num_images, x1_batch.shape[0])
    
    plt.figure(figsize=(15, 5 * num_images))
    for i in range(num_images):
        
        # We no longer need np.squeeze() because our arrays are properly 3-channel RGB
        x1_img = x1_batch[i]
        x2_img = x2_batch[i]
        fused_img = fused_batch[i]
        
        # Plot X1 (Left)
        plt.subplot(num_images, 3, i * 3 + 1)
        plt.imshow(x1_img)
        plt.title(f"X1 - {i+1}")
        plt.axis('off')
        
        # Plot X2 (Center)
        plt.subplot(num_images, 3, i * 3 + 2)
        plt.imshow(x2_img)
        plt.title(f"X2 - {i+1}")
        plt.axis('off')
        
        # Plot Fused (Right)
        plt.subplot(num_images, 3, i * 3 + 3)
        plt.imshow(fused_img)
        plt.title(f"Fused Output - {i+1}")
        plt.axis('off')
        
    plt.tight_layout()
    plt.show()

# 1. Grab a random batch of 4 indices
num_samples = X1_test.shape[0]
random_indices = np.random.choice(num_samples, size=4, replace=False)

# 2. Sample the separate test arrays
x1_sample = X1_test[random_indices]
x2_sample = X2_test[random_indices]

# 3. Run Inference via List passing
print("Running inference...")
predictions = fusion_model.predict([x1_sample, x2_sample])

print("Prediction Shape :", predictions.shape)
print("Min :", predictions.min())
print("Max :", predictions.max())
print("Mean:", predictions.mean())

# Clamp the predicted values
predictions = np.clip(predictions, 0.0, 1.0)

# 4. Un-process the inputs for visualization

# Reverse scaling back to [0, 1] from [0, 255] for matplotlib
x1_sample = x1_sample / 255.0
x2_sample = x2_sample / 255.0

# Reverse scaling back to [0, 1] from [-1, 1] for matplotlib
# x1_sample = (x1_sample + 1.0) / 2.0
# x2_sample = (x2_sample + 1.0) / 2.0

# Add a safety clip to prevent floating point rendering artifacts
x1_sample = np.clip(x1_sample, 0.0, 1.0)
x2_sample = np.clip(x2_sample, 0.0, 1.0)

# 5. Plot the final results!
show_fusion_results(x1_sample, x2_sample, predictions, num_images=4)
# Out:
# Running inference...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Prediction Shape : (4, 256, 256, 3)
# Min : 7.276138e-06
# Max : 0.9999907
# Mean: 0.28481635

# %%
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import FileLink, display

def plot_training_metrics_optimized(history_obj, title_name):
    """
    Generates publication-quality dual-axis plots with specific color grading.
    Both Warm-up and Fine-tuning stages are locked into a symmetric 8x8 grid matrix
    (8 X-axis intervals by 8 Y-axis intervals) with crisp integer labels for Epochs.
    """
    h = history_obj.history if hasattr(history_obj, 'history') else history_obj
    total_epochs = len(h['loss'])
    epochs = range(1, total_epochs + 1)
    
    plt.rcParams['font.family'] = 'sans-serif'
    plt.rcParams['axes.edgecolor'] = '#CCCCCC'
    plt.rcParams['axes.linewidth'] = 1.0
    
    fig, ax1 = plt.subplots(figsize=(8.5, 5.5), dpi=300)
    
    # ---------------- Left Y-Axis: PSNR Values (BLUE Theme) ----------------
    line1 = ax1.plot(epochs, h['psnr'], color='#1F77B4', linestyle='-', linewidth=2.2, label='Train PSNR', zorder=3)
    line2 = ax1.plot(epochs, h['val_psnr'], color='#4A90E2', linestyle='-.', linewidth=2.2, label='Validation PSNR', zorder=3)
    
    ax1.set_xlabel('Epochs', fontsize=12, labelpad=10)
    ax1.set_ylabel('PSNR (dB)', fontsize=12, labelpad=10, color='#1F77B4', fontweight='bold')
    
    # Force X-axis limits securely based on epoch length
    ax1.set_xlim(1, total_epochs)
    
    # AUTO-GRID: Force exactly 8 intervals, safely mapped to clean integers
    x_ticks = np.linspace(1, total_epochs, 9).astype(int)
    x_ticks = np.unique(x_ticks)  # Prevents duplicate ticks if total_epochs < 8
    ax1.set_xticks(x_ticks)
    
    # ---------------- Left Axis (PSNR) Bounds & Ticks ----------------
    if "Fine" in title_name:
        # Fine-tuning: Ticks from 10 to 42, limits expanded to 8.5 and 43.5 for padding
        ax1.set_ylim(8.5, 43.5)
        ax1.set_yticks(np.linspace(10, 42, 9))
    else:
        # Warm-up: Keep tight bounds exactly as originally specified
        ax1.set_ylim(10, 42)
        ax1.set_yticks(np.linspace(10, 42, 9))
        
    ax1.tick_params(axis='y', labelsize=10.5, labelcolor='#1F77B4')
    
    # OPTIMIZED GRID: Forms a crisp symmetric matrix background
    ax1.grid(True, linestyle=':', alpha=0.75, color='#B0B0B0', linewidth=0.8, zorder=1)
    
    # ---------------- Right Y-Axis: Loss Values (RED Theme) ----------------
    ax2 = ax1.twinx()
    line3 = ax2.plot(epochs, h['loss'], color='#D62728', linestyle='--', linewidth=2.0, label='Train Loss', zorder=3)
    line4 = ax2.plot(epochs, h['val_loss'], color='#FF6B6B', linestyle=':', linewidth=2.0, label='Validation Loss', zorder=3)
    
    ax2.set_ylabel('Loss', fontsize=12, labelpad=10, color='#D62728', fontweight='bold')
    
    # ---------------- Right Axis (Loss) Bounds & Ticks ----------------
    if "Fine" in title_name:
        # Fine-tuning: Ticks from 0.009 to 0.073, limits expanded slightly for padding
        ax2.set_ylim(0.005, 0.077)
        ax2.set_yticks(np.linspace(0.009, 0.073, 9))
    else:
        # Warm-up: Keep original tight bounds
        ax2.set_ylim(0.0, 0.40)
        ax2.set_yticks(np.linspace(0.0, 0.40, 9))
        
    ax2.tick_params(axis='y', labelsize=10.5, labelcolor='#D62728')
    
    # ---------------- Legend Layout (Inside Frame) ----------------
    all_lines = line1 + line2 + line3 + line4
    all_labels = [l.get_label() for l in all_lines]
    
    leg = ax1.legend(
        all_lines, 
        all_labels, 
        loc='center right', 
        frameon=True, 
        facecolor='white', 
        edgecolor='#E0E0E0', 
        fontsize=10
    )
    
    if leg:
        leg.set_zorder(4)
    
    plt.title(title_name, fontsize=14, fontweight='bold', pad=15)
    plt.tight_layout()
    
    save_filename = title_name.lower().replace(' ', '_') + '_curve.png'
    plt.savefig(save_filename, dpi=300, bbox_inches='tight')
    plt.show()
    return save_filename

# --- Execution Block ---
fn_warmup = plot_training_metrics_optimized(history_warmup, 'Warm-up Training Stage')
display(FileLink(fn_warmup))

fn_finetune = plot_training_metrics_optimized(history_finetune, 'Fine-tuning Training Stage')
display(FileLink(fn_finetune))
# Out:
# /kaggle/working/warm-up_training_stage_curve.png
# /kaggle/working/fine-tuning_training_stage_curve.png

# %%
# --- Rename and Save the Final Trained Model ---

# Update the model's internal name attribute for EfficientNetB0 CT-MRI
fusion_model.name = "EfficientNetB0_CT_MRI"

# Construct the dynamic file path using the updated name and the final Test PSNR score
model_save_path = f"/kaggle/working/{fusion_model.name}_(PSNR_{final_psnr:.2f}dB).keras"

print(f"Saving model to: {model_save_path}")
fusion_model.save(model_save_path)
print("Model saved successfully!")
# Out:
# Saving model to: /kaggle/working/EfficientNetB0_CT_MRI_(PSNR_38.97dB).keras
# Model saved successfully!
